# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# 4. Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# 5. Perform an API call with the OpenWeatherMap.

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6. Retrieve the following information from the API call:
    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record %s of set %s | %s" % (record_count,set_count,city))
       
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        print("city_lat",city_lat)
        city_lng = city_weather["coord"]["lon"]
        print("city_lng",city_lng)
        city_max_temp = city_weather["main"]["temp_max"]
        print("city_lng",city_lng)
        city_humidity = city_weather["main"]["humidity"]
        print("city_humidity",city_humidity)
        city_clouds = city_weather["clouds"]["all"]
        print("city_clouds",city_clouds)
        city_wind = city_weather["wind"]["speed"]
        print("city_wind",city_wind)
        city_country = city_weather["sys"]["country"]
        print("city_country",city_country)
        city_description = city_weather["weather"]["description"]
        print("city_description",city_description)
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | darnah
# city_lat 32.767
# city_lng 22.6367
# city_lng 22.6367
# city_humidity 65
# city_clouds 41
# city_wind 22.08
# city_country LY
# City not found. Skipping...
# Processing Record 2 of set 1 | ushuaia
# city_lat -54.8
# city_lng -68.3
# city_lng -68.3
# city_humidity 81
# city_clouds 40
# city_wind 8.05
# city_country AR
# City not found. Skipping...
# Processing Record 3 of set 1 | butaritari
# city_lat 3.0707
# city_lng 172.7902
# city_lng 172.7902
# city_humidity 78
# city_clouds 56
# city_wind 19.37
# city_country KI
# City not found. Skipping...
# Processing Record 4 of set 1 | smithers
# city_lat 54.7804
# city_lng -127.1743
# city_lng -127.1743
# city_humidity 87
# city_clouds 90
# city_wind 5.75
# city_country CA
# City not found. Skipping...
# Processing Record 5 of set 1 | nha trang
# city_lat 12.25
# city_lng 109.1833
# city_lng 109.1833
# city_humidity 57
# city_clouds 20
# city_wind 19.57
# city_country VN
# City not found. Skipping...
# Processing Record 6 of set 1 | pacific grove
# city_lat 36.6177
# city_lng -121.9166
# city_lng -121.9166
# city_humidity 93
# city_clouds 90
# city_wind 9.22
# city_country US
# City not found. Skipping...
# Processing Record 7 of set 1 | carbonia
# city_lat 39.1672
# city_lng 8.5222
# city_lng 8.5222
# city_humidity 100
# city_clouds 40
# city_wind 3.44
# city_country IT
# City not found. Skipping...
# Processing Record 8 of set 1 | ponta do sol
# city_lat 32.6667
# city_lng -17.1
# city_lng -17.1
# city_humidity 66
# city_clouds 56
# city_wind 3
# city_country PT
# City not found. Skipping...
# Processing Record 9 of set 1 | rayevskiy
# city_lat 54.0658
# city_lng 54.9468
# city_lng 54.9468
# city_humidity 92
# city_clouds 100
# city_wind 16.93
# city_country RU
# City not found. Skipping...
# Processing Record 10 of set 1 | ribeira grande
# city_lat 38.5167
# city_lng -28.7
# city_lng -28.7
# city_humidity 86
# city_clouds 100
# city_wind 26.64
# city_country PT
# City not found. Skipping...
# Processing Record 11 of set 1 | nouadhibou
# city_lat 20.931
# city_lng -17.0347
# city_lng -17.0347
# city_humidity 29
# city_clouds 100
# city_wind 19.57
# city_country MR
# City not found. Skipping...
# Processing Record 12 of set 1 | namibe
# city_lat -15.1961
# city_lng 12.1522
# city_lng 12.1522
# city_humidity 68
# city_clouds 100
# city_wind 3.42
# city_country AO
# City not found. Skipping...
# Processing Record 13 of set 1 | hilo
# city_lat 19.7297
# city_lng -155.09
# city_lng -155.09
# city_humidity 78
# city_clouds 40
# city_wind 3.44
# city_country US
# City not found. Skipping...
# Processing Record 14 of set 1 | atuona
# city_lat -9.8
# city_lng -139.0333
# city_lng -139.0333
# city_humidity 81
# city_clouds 3
# city_wind 15.61
# city_country PF
# City not found. Skipping...
# Processing Record 15 of set 1 | tulare
# city_lat 36.2666
# city_lng -118.8009
# city_lng -118.8009
# city_humidity 71
# city_clouds 1
# city_wind 3.44
# city_country US
# City not found. Skipping...
# Processing Record 16 of set 1 | rikitea
# city_lat -23.1203
# city_lng -134.9692
# city_lng -134.9692
# city_humidity 73
# city_clouds 0
# city_wind 11.9
# city_country PF
# City not found. Skipping...
# Processing Record 17 of set 1 | bairiki
# city_lat 1.3292
# city_lng 172.9752
# city_lng 172.9752
# city_humidity 78
# city_clouds 20
# city_wind 13.8
# city_country KI
# City not found. Skipping...
# Processing Record 18 of set 1 | carnarvon
# city_lat -24.8667
# city_lng 113.6333
# city_lng 113.6333
# city_humidity 66
# city_clouds 78
# city_wind 19.57
# city_country AU
# City not found. Skipping...
# Processing Record 19 of set 1 | saskylakh
# city_lat 71.9167
# city_lng 114.0833
# city_lng 114.0833
# city_humidity 84
# city_clouds 79
# city_wind 5.82
# city_country RU
# City not found. Skipping...
# Processing Record 20 of set 1 | cockburn town
# city_lat 21.4612
# city_lng -71.1419
# city_lng -71.1419
# city_humidity 75
# city_clouds 100
# city_wind 7.36
# city_country TC
# City not found. Skipping...
# Processing Record 21 of set 1 | lebu
# city_lat -37.6167
# city_lng -73.65
# city_lng -73.65
# city_humidity 90
# city_clouds 0
# city_wind 18.07
# city_country CL
# City not found. Skipping...
# Processing Record 22 of set 1 | kodiak
# city_lat 57.79
# city_lng -152.4072
# city_lng -152.4072
# city_humidity 100
# city_clouds 90
# city_wind 8.03
# city_country US
# City not found. Skipping...
# Processing Record 23 of set 1 | hobart
# city_lat -42.8794
# city_lng 147.3294
# city_lng 147.3294
# city_humidity 48
# city_clouds 75
# city_wind 20.71
# city_country AU
# City not found. Skipping...
# Processing Record 24 of set 1 | punta arenas
# city_lat -53.15
# city_lng -70.9167
# city_lng -70.9167
# city_humidity 81
# city_clouds 75
# city_wind 11.5
# city_country CL
# City not found. Skipping...
# Processing Record 25 of set 1 | richards bay
# city_lat -28.783
# city_lng 32.0377
# city_lng 32.0377
# city_humidity 80
# city_clouds 99
# city_wind 8.81
# city_country ZA
# City not found. Skipping...
# Processing Record 26 of set 1 | port alfred
# city_lat -33.5906
# city_lng 26.891
# city_lng 26.891
# city_humidity 90
# city_clouds 8
# city_wind 5.01
# city_country ZA
# City not found. Skipping...
# Processing Record 27 of set 1 | sitka
# city_lat 57.0531
# city_lng -135.33
# city_lng -135.33
# city_humidity 87
# city_clouds 90
# city_wind 12.66
# city_country US
# City not found. Skipping...
# Processing Record 28 of set 1 | nuuk
# city_lat 64.1835
# city_lng -51.7216
# city_lng -51.7216
# city_humidity 93
# city_clouds 90
# city_wind 31.07
# city_country GL
# City not found. Skipping...
# Processing Record 29 of set 1 | antsohihy
# city_lat -14.8796
# city_lng 47.9875
# city_lng 47.9875
# city_humidity 68
# city_clouds 28
# city_wind 4.25
# city_country MG
# City not found. Skipping...
# Processing Record 30 of set 1 | hermanus
# city_lat -34.4187
# city_lng 19.2345
# city_lng 19.2345
# city_humidity 62
# city_clouds 0
# city_wind 3
# city_country ZA
# City not found. Skipping...
# Processing Record 31 of set 1 | airai
# city_lat -8.9266
# city_lng 125.4092
# city_lng 125.4092
# city_humidity 100
# city_clouds 100
# city_wind 1.54
# city_country TL
# City not found. Skipping...
# Processing Record 32 of set 1 | pevek
# city_lat 69.7008
# city_lng 170.3133
# city_lng 170.3133
# city_humidity 85
# city_clouds 21
# city_wind 1.81
# city_country RU
# City not found. Skipping...
# Processing Record 33 of set 1 | cidreira
# city_lat -30.1811
# city_lng -50.2056
# city_lng -50.2056
# city_humidity 89
# city_clouds 100
# city_wind 6.87
# city_country BR
# City not found. Skipping...
# Processing Record 34 of set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of set 1 | apac
# city_lat 1.9756
# city_lng 32.5386
# city_lng 32.5386
# city_humidity 42
# city_clouds 100
# city_wind 2.55
# city_country UG
# City not found. Skipping...
# Processing Record 36 of set 1 | svetlaya
# city_lat 46.5389
# city_lng 138.3297
# city_lng 138.3297
# city_humidity 76
# city_clouds 2
# city_wind 1.86
# city_country RU
# City not found. Skipping...
# Processing Record 37 of set 1 | busselton
# city_lat -33.65
# city_lng 115.3333
# city_lng 115.3333
# city_humidity 23
# city_clouds 0
# city_wind 5.99
# city_country AU
# City not found. Skipping...
# Processing Record 38 of set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of set 1 | cochrane
# city_lat 51.1834
# city_lng -114.4687
# city_lng -114.4687
# city_humidity 68
# city_clouds 75
# city_wind 4.61
# city_country CA
# City not found. Skipping...
# Processing Record 40 of set 1 | chernyy yar
# city_lat 48.0624
# city_lng 46.1091
# city_lng 46.1091
# city_humidity 89
# city_clouds 100
# city_wind 4.21
# city_country RU
# City not found. Skipping...
# Processing Record 41 of set 1 | nikolskoye
# city_lat 59.7035
# city_lng 30.7861
# city_lng 30.7861
# city_humidity 92
# city_clouds 90
# city_wind 4.47
# city_country RU
# City not found. Skipping...
# Processing Record 42 of set 1 | odweyne
# city_lat 9.4092
# city_lng 45.064
# city_lng 45.064
# city_humidity 42
# city_clouds 0
# city_wind 10.85
# city_country SO
# City not found. Skipping...
# Processing Record 43 of set 1 | nome
# city_lat 64.5011
# city_lng -165.4064
# city_lng -165.4064
# city_humidity 72
# city_clouds 40
# city_wind 6.24
# city_country US
# City not found. Skipping...
# Processing Record 44 of set 1 | visconde do rio branco
# city_lat -21.0103
# city_lng -42.8406
# city_lng -42.8406
# city_humidity 89
# city_clouds 47
# city_wind 4
# city_country BR
# City not found. Skipping...
# Processing Record 45 of set 1 | halalo
# City not found. Skipping...
# Processing Record 46 of set 1 | albany
# city_lat 42.6001
# city_lng -73.9662
# city_lng -73.9662
# city_humidity 63
# city_clouds 100
# city_wind 5.99
# city_country US
# City not found. Skipping...
# Processing Record 47 of set 1 | provideniya
# city_lat 64.3833
# city_lng -173.3
# city_lng -173.3
# city_humidity 84
# city_clouds 88
# city_wind 9.57
# city_country RU
# City not found. Skipping...
# Processing Record 48 of set 1 | iqaluit
# city_lat 63.7506
# city_lng -68.5145
# city_lng -68.5145
# city_humidity 77
# city_clouds 90
# city_wind 2.3
# city_country CA
# City not found. Skipping...
# Processing Record 49 of set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of set 1 | denizli
# city_lat 37.8402
# city_lng 29.0698
# city_lng 29.0698
# city_humidity 93
# city_clouds 90
# city_wind 9.22
# city_country TR
# City not found. Skipping...
# Processing Record 1 of set 2 | san cristobal
# city_lat 7.7669
# city_lng -72.225
# city_lng -72.225
# city_humidity 86
# city_clouds 31
# city_wind 2.66
# city_country VE
# City not found. Skipping...
# Processing Record 2 of set 2 | alyangula
# city_lat -13.8483
# city_lng 136.4192
# city_lng 136.4192
# city_humidity 94
# city_clouds 90
# city_wind 14.97
# city_country AU
# City not found. Skipping...
# Processing Record 3 of set 2 | cape town
# city_lat -33.9258
# city_lng 18.4232
# city_lng 18.4232
# city_humidity 73
# city_clouds 0
# city_wind 5.75
# city_country ZA
# City not found. Skipping...
# Processing Record 4 of set 2 | svilajnac
# city_lat 44.2337
# city_lng 21.1967
# city_lng 21.1967
# city_humidity 100
# city_clouds 75
# city_wind 4.14
# city_country RS
# City not found. Skipping...
# Processing Record 5 of set 2 | arraial do cabo
# city_lat -22.9661
# city_lng -42.0278
# city_lng -42.0278
# city_humidity 84
# city_clouds 0
# city_wind 27.98
# city_country BR
# City not found. Skipping...
# Processing Record 6 of set 2 | faanui
# city_lat -16.4833
# city_lng -151.75
# city_lng -151.75
# city_humidity 78
# city_clouds 0
# city_wind 13.18
# city_country PF
# City not found. Skipping...
# Processing Record 7 of set 2 | kapaa
# city_lat 22.0752
# city_lng -159.319
# city_lng -159.319
# city_humidity 83
# city_clouds 75
# city_wind 6.91
# city_country US
# City not found. Skipping...
# Processing Record 8 of set 2 | andros town
# city_lat 24.7
# city_lng -77.7667
# city_lng -77.7667
# city_humidity 68
# city_clouds 40
# city_wind 4.61
# city_country BS
# City not found. Skipping...
# Processing Record 9 of set 2 | vaini
# city_lat -21.2
# city_lng -175.2
# city_lng -175.2
# city_humidity 89
# city_clouds 75
# city_wind 4.61
# city_country TO
# City not found. Skipping...
# Processing Record 10 of set 2 | constitucion
# city_lat -35.3333
# city_lng -72.4167
# city_lng -72.4167
# city_humidity 70
# city_clouds 0
# city_wind 7.02
# city_country CL
# City not found. Skipping...
# Processing Record 11 of set 2 | dolinsk
# city_lat 47.35
# city_lng 142.8
# city_lng 142.8
# city_humidity 56
# city_clouds 87
# city_wind 4.47
# city_country RU
# City not found. Skipping...
# Processing Record 12 of set 2 | arbagar
# city_lat 51.9438
# city_lng 116.2805
# city_lng 116.2805
# city_humidity 82
# city_clouds 100
# city_wind 7.99
# city_country RU
# City not found. Skipping...
# Processing Record 13 of set 2 | tiksi
# city_lat 71.6872
# city_lng 128.8694
# city_lng 128.8694
# city_humidity 88
# city_clouds 100
# city_wind 8.7
# city_country RU
# City not found. Skipping...
# Processing Record 14 of set 2 | port moresby
# city_lat -9.4431
# city_lng 147.1797
# city_lng 147.1797
# city_humidity 62
# city_clouds 40
# city_wind 11.5
# city_country PG
# City not found. Skipping...
# Processing Record 15 of set 2 | puerto ayora
# city_lat -0.7393
# city_lng -90.3518
# city_lng -90.3518
# city_humidity 96
# city_clouds 7
# city_wind 1.99
# city_country EC
# City not found. Skipping...
# Processing Record 16 of set 2 | okhotsk
# city_lat 59.3833
# city_lng 143.3
# city_lng 143.3
# city_humidity 79
# city_clouds 29
# city_wind 15.39
# city_country RU
# City not found. Skipping...
# Processing Record 17 of set 2 | samus
# city_lat 56.7475
# city_lng 84.6992
# city_lng 84.6992
# city_humidity 75
# city_clouds 100
# city_wind 8.99
# city_country RU
# City not found. Skipping...
# Processing Record 18 of set 2 | klaksvik
# city_lat 62.2266
# city_lng -6.589
# city_lng -6.589
# city_humidity 93
# city_clouds 75
# city_wind 32.21
# city_country FO
# City not found. Skipping...
# Processing Record 19 of set 2 | paraiso
# city_lat 9.8383
# city_lng -83.8656
# city_lng -83.8656
# city_humidity 68
# city_clouds 0
# city_wind 6.91
# city_country CR
# City not found. Skipping...
# Processing Record 20 of set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of set 2 | jamestown
# city_lat 42.097
# city_lng -79.2353
# city_lng -79.2353
# city_humidity 93
# city_clouds 90
# city_wind 14.97
# city_country US
# City not found. Skipping...
# Processing Record 22 of set 2 | longyearbyen
# city_lat 78.2186
# city_lng 15.6401
# city_lng 15.6401
# city_humidity 80
# city_clouds 75
# city_wind 4.61
# city_country SJ
# City not found. Skipping...
# Processing Record 23 of set 2 | brigantine
# city_lat 39.4101
# city_lng -74.3646
# city_lng -74.3646
# city_humidity 69
# city_clouds 1
# city_wind 8.05
# city_country US
# City not found. Skipping...
# Processing Record 24 of set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of set 2 | tsihombe
# City not found. Skipping...
# Processing Record 26 of set 2 | saint george
# city_lat 37.1041
# city_lng -113.5841
# city_lng -113.5841
# city_humidity 42
# city_clouds 1
# city_wind 3.62
# city_country US
# City not found. Skipping...
# Processing Record 27 of set 2 | hasaki
# city_lat 35.7333
# city_lng 140.8333
# city_lng 140.8333
# city_humidity 61
# city_clouds 75
# city_wind 10.36
# city_country JP
# City not found. Skipping...
# Processing Record 28 of set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of set 2 | leningradskiy
# city_lat 69.3833
# city_lng 178.4167
# city_lng 178.4167
# city_humidity 85
# city_clouds 100
# city_wind 4.94
# city_country RU
# City not found. Skipping...
# Processing Record 30 of set 2 | souillac
# city_lat -20.5167
# city_lng 57.5167
# city_lng 57.5167
# city_humidity 70
# city_clouds 75
# city_wind 13.8
# city_country MU
# City not found. Skipping...
# Processing Record 31 of set 2 | santa cruz del sur
# city_lat 20.7147
# city_lng -77.9956
# city_lng -77.9956
# city_humidity 93
# city_clouds 100
# city_wind 8.93
# city_country CU
# City not found. Skipping...
# Processing Record 32 of set 2 | dikson
# city_lat 73.5069
# city_lng 80.5464
# city_lng 80.5464
# city_humidity 85
# city_clouds 3
# city_wind 11.07
# city_country RU
# City not found. Skipping...
# Processing Record 33 of set 2 | vestmannaeyjar
# city_lat 63.4427
# city_lng -20.2734
# city_lng -20.2734
# city_humidity 72
# city_clouds 47
# city_wind 18.66
# city_country IS
# City not found. Skipping...
# Processing Record 34 of set 2 | hualmay
# city_lat -11.0964
# city_lng -77.6139
# city_lng -77.6139
# city_humidity 84
# city_clouds 92
# city_wind 6.89
# city_country PE
# City not found. Skipping...
# Processing Record 35 of set 2 | albania
# city_lat 41
# city_lng 20
# city_lng 20
# city_humidity 86
# city_clouds 0
# city_wind 2.3
# city_country AL
# City not found. Skipping...
# Processing Record 36 of set 2 | bathurst
# city_lat -33.4166
# city_lng 149.5806
# city_lng 149.5806
# city_humidity 28
# city_clouds 69
# city_wind 3
# city_country AU
# City not found. Skipping...
# Processing Record 37 of set 2 | kathmandu
# city_lat 27.7167
# city_lng 85.3167
# city_lng 85.3167
# city_humidity 48
# city_clouds 20
# city_wind 4.61
# city_country NP
# City not found. Skipping...
# Processing Record 38 of set 2 | hithadhoo
# city_lat -0.6
# city_lng 73.0833
# city_lng 73.0833
# city_humidity 72
# city_clouds 96
# city_wind 9.19
# city_country MV
# City not found. Skipping...
# Processing Record 39 of set 2 | mexico
# city_lat 15.0646
# city_lng 120.7198
# city_lng 120.7198
# city_humidity 48
# city_clouds 75
# city_wind 4.61
# city_country PH
# City not found. Skipping...
# Processing Record 40 of set 2 | kaeo
# city_lat -35.1
# city_lng 173.7833
# city_lng 173.7833
# city_humidity 89
# city_clouds 2
# city_wind 5.99
# city_country NZ
# City not found. Skipping...
# Processing Record 41 of set 2 | vanimo
# city_lat -2.6741
# city_lng 141.3028
# city_lng 141.3028
# city_humidity 71
# city_clouds 100
# city_wind 7.52
# city_country PG
# City not found. Skipping...
# Processing Record 42 of set 2 | playas
# city_lat -2.6333
# city_lng -80.3833
# city_lng -80.3833
# city_humidity 84
# city_clouds 100
# city_wind 7.96
# city_country EC
# City not found. Skipping...
# Processing Record 43 of set 2 | norman wells
# city_lat 65.282
# city_lng -126.8329
# city_lng -126.8329
# city_humidity 84
# city_clouds 1
# city_wind 5.75
# city_country CA
# City not found. Skipping...
# Processing Record 44 of set 2 | nemuro
# city_lat 43.3236
# city_lng 145.575
# city_lng 145.575
# city_humidity 58
# city_clouds 75
# city_wind 3.44
# city_country JP
# City not found. Skipping...
# Processing Record 45 of set 2 | arlit
# city_lat 18.7369
# city_lng 7.3853
# city_lng 7.3853
# city_humidity 22
# city_clouds 99
# city_wind 7.85
# city_country NE
# City not found. Skipping...
# Processing Record 46 of set 2 | bredasdorp
# city_lat -34.5322
# city_lng 20.0403
# city_lng 20.0403
# city_humidity 73
# city_clouds 0
# city_wind 4.61
# city_country ZA
# City not found. Skipping...
# Processing Record 47 of set 2 | ola
# city_lat 59.5833
# city_lng 151.2833
# city_lng 151.2833
# city_humidity 89
# city_clouds 100
# city_wind 12.86
# city_country RU
# City not found. Skipping...
# Processing Record 48 of set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of set 2 | hat yai
# city_lat 7.0084
# city_lng 100.4767
# city_lng 100.4767
# city_humidity 65
# city_clouds 75
# city_wind 14.97
# city_country TH
# City not found. Skipping...
# Processing Record 50 of set 2 | sao jose da coroa grande
# city_lat -8.8978
# city_lng -35.1478
# city_lng -35.1478
# city_humidity 84
# city_clouds 0
# city_wind 9.55
# city_country BR
# City not found. Skipping...
# Processing Record 1 of set 3 | beloha
# city_lat -25.1667
# city_lng 45.05
# city_lng 45.05
# city_humidity 33
# city_clouds 44
# city_wind 7.34
# city_country MG
# City not found. Skipping...
# Processing Record 2 of set 3 | tumannyy
# City not found. Skipping...
# Processing Record 3 of set 3 | mahebourg
# city_lat -20.4081
# city_lng 57.7
# city_lng 57.7
# city_humidity 70
# city_clouds 75
# city_wind 13.8
# city_country MU
# City not found. Skipping...
# Processing Record 4 of set 3 | bengkulu
# city_lat -3.8004
# city_lng 102.2655
# city_lng 102.2655
# city_humidity 61
# city_clouds 100
# city_wind 7.38
# city_country ID
# City not found. Skipping...
# Processing Record 5 of set 3 | olutanga
# city_lat 7.3106
# city_lng 122.8464
# city_lng 122.8464
# city_humidity 77
# city_clouds 100
# city_wind 3.91
# city_country PH
# City not found. Skipping...
# Processing Record 6 of set 3 | margate
# city_lat 51.3813
# city_lng 1.3862
# city_lng 1.3862
# city_humidity 81
# city_clouds 100
# city_wind 4
# city_country GB
# City not found. Skipping...
# Processing Record 7 of set 3 | champoton
# city_lat 19.35
# city_lng -90.7167
# city_lng -90.7167
# city_humidity 74
# city_clouds 92
# city_wind 8.39
# city_country MX
# City not found. Skipping...
# Processing Record 8 of set 3 | myitkyina
# city_lat 25.3833
# city_lng 97.4
# city_lng 97.4
# city_humidity 32
# city_clouds 45
# city_wind 1.03
# city_country MM
# City not found. Skipping...
# Processing Record 9 of set 3 | harper
# city_lat 4.375
# city_lng -7.7169
# city_lng -7.7169
# city_humidity 84
# city_clouds 7
# city_wind 4.03
# city_country LR
# City not found. Skipping...
# Processing Record 10 of set 3 | kijang
# city_lat 35.2442
# city_lng 129.2139
# city_lng 129.2139
# city_humidity 10
# city_clouds 0
# city_wind 13.8
# city_country KR
# City not found. Skipping...
# Processing Record 11 of set 3 | izhma
# city_lat 65.0083
# city_lng 53.9113
# city_lng 53.9113
# city_humidity 90
# city_clouds 100
# city_wind 4.45
# city_country RU
# City not found. Skipping...
# Processing Record 12 of set 3 | tabuk
# city_lat 17.4189
# city_lng 121.4443
# city_lng 121.4443
# city_humidity 92
# city_clouds 100
# city_wind 12.03
# city_country PH
# City not found. Skipping...
# Processing Record 13 of set 3 | castro
# city_lat -24.7911
# city_lng -50.0119
# city_lng -50.0119
# city_humidity 95
# city_clouds 100
# city_wind 8.08
# city_country BR
# City not found. Skipping...
# Processing Record 14 of set 3 | victoria
# city_lat 22.2855
# city_lng 114.1577
# city_lng 114.1577
# city_humidity 48
# city_clouds 23
# city_wind 16.28
# city_country HK
# City not found. Skipping...
# Processing Record 15 of set 3 | bluff
# city_lat -46.6
# city_lng 168.3333
# city_lng 168.3333
# city_humidity 71
# city_clouds 100
# city_wind 16.44
# city_country NZ
# City not found. Skipping...
# Processing Record 16 of set 3 | kurilsk
# city_lat 45.2333
# city_lng 147.8833
# city_lng 147.8833
# city_humidity 93
# city_clouds 100
# city_wind 15.61
# city_country RU
# City not found. Skipping...
# Processing Record 17 of set 3 | villa maria
# city_lat -32.4075
# city_lng -63.2402
# city_lng -63.2402
# city_humidity 92
# city_clouds 0
# city_wind 1.99
# city_country AR
# City not found. Skipping...
# Processing Record 18 of set 3 | lahaina
# city_lat 20.8783
# city_lng -156.6825
# city_lng -156.6825
# city_humidity 68
# city_clouds 1
# city_wind 6.13
# city_country US
# City not found. Skipping...
# Processing Record 19 of set 3 | bumbesti-jiu
# city_lat 45.1667
# city_lng 23.4
# city_lng 23.4
# city_humidity 87
# city_clouds 90
# city_wind 3.31
# city_country RO
# City not found. Skipping...
# Processing Record 20 of set 3 | yumen
# city_lat 40.2833
# city_lng 97.2
# city_lng 97.2
# city_humidity 75
# city_clouds 0
# city_wind 29.95
# city_country CN
# City not found. Skipping...
# Processing Record 21 of set 3 | hurghada
# city_lat 27.2574
# city_lng 33.8129
# city_lng 33.8129
# city_humidity 38
# city_clouds 0
# city_wind 5.75
# city_country EG
# City not found. Skipping...
# Processing Record 22 of set 3 | bilibino
# city_lat 68.0546
# city_lng 166.4372
# city_lng 166.4372
# city_humidity 84
# city_clouds 100
# city_wind 1.54
# city_country RU
# City not found. Skipping...
# Processing Record 23 of set 3 | barrow
# city_lat 71.2906
# city_lng -156.7887
# city_lng -156.7887
# city_humidity 71
# city_clouds 90
# city_wind 18.41
# city_country US
# City not found. Skipping...
# Processing Record 24 of set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of set 3 | luderitz
# city_lat -26.6481
# city_lng 15.1594
# city_lng 15.1594
# city_humidity 59
# city_clouds 0
# city_wind 9.73
# city_country NA
# City not found. Skipping...
# Processing Record 26 of set 3 | cap malheureux
# city_lat -19.9842
# city_lng 57.6142
# city_lng 57.6142
# city_humidity 71
# city_clouds 94
# city_wind 11.99
# city_country MU
# City not found. Skipping...
# Processing Record 27 of set 3 | moron
# city_lat -34.6534
# city_lng -58.6198
# city_lng -58.6198
# city_humidity 91
# city_clouds 98
# city_wind 1.99
# city_country AR
# City not found. Skipping...
# Processing Record 28 of set 3 | pangnirtung
# city_lat 66.1451
# city_lng -65.7125
# city_lng -65.7125
# city_humidity 86
# city_clouds 100
# city_wind 4.97
# city_country CA
# City not found. Skipping...
# Processing Record 29 of set 3 | khatanga
# city_lat 71.9667
# city_lng 102.5
# city_lng 102.5
# city_humidity 85
# city_clouds 17
# city_wind 9.86
# city_country RU
# City not found. Skipping...
# Processing Record 30 of set 3 | san patricio
# city_lat 28.017
# city_lng -97.5169
# city_lng -97.5169
# city_humidity 87
# city_clouds 20
# city_wind 5.75
# city_country US
# City not found. Skipping...
# Processing Record 31 of set 3 | saint-augustin
# city_lat 51.226
# city_lng -58.6502
# city_lng -58.6502
# city_humidity 93
# city_clouds 100
# city_wind 11.92
# city_country CA
# City not found. Skipping...
# Processing Record 32 of set 3 | kabompo
# city_lat -13.5927
# city_lng 24.2008
# city_lng 24.2008
# city_humidity 85
# city_clouds 100
# city_wind 6.22
# city_country ZM
# City not found. Skipping...
# Processing Record 33 of set 3 | blagoyevo
# city_lat 63.3667
# city_lng 47.9167
# city_lng 47.9167
# city_humidity 89
# city_clouds 5
# city_wind 2.86
# city_country RU
# City not found. Skipping...
# Processing Record 34 of set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 35 of set 3 | ramos arizpe
# city_lat 25.55
# city_lng -100.9667
# city_lng -100.9667
# city_humidity 60
# city_clouds 68
# city_wind 3.36
# city_country MX
# City not found. Skipping...
# Processing Record 36 of set 3 | hyderabad
# city_lat 17.3753
# city_lng 78.4744
# city_lng 78.4744
# city_humidity 44
# city_clouds 0
# city_wind 9.22
# city_country IN
# City not found. Skipping...
# Processing Record 37 of set 3 | bathsheba
# city_lat 13.2167
# city_lng -59.5167
# city_lng -59.5167
# city_humidity 73
# city_clouds 40
# city_wind 17.27
# city_country BB
# City not found. Skipping...
# Processing Record 38 of set 3 | mataura
# city_lat -46.1927
# city_lng 168.8643
# city_lng 168.8643
# city_humidity 78
# city_clouds 100
# city_wind 4.99
# city_country NZ
# City not found. Skipping...
# Processing Record 39 of set 3 | upernavik
# city_lat 72.7868
# city_lng -56.1549
# city_lng -56.1549
# city_humidity 81
# city_clouds 0
# city_wind 7.52
# city_country GL
# City not found. Skipping...
# Processing Record 40 of set 3 | iquitos
# city_lat -3.7481
# city_lng -73.2472
# city_lng -73.2472
# city_humidity 94
# city_clouds 75
# city_wind 2.1
# city_country PE
# City not found. Skipping...
# Processing Record 41 of set 3 | avarua
# city_lat -21.2078
# city_lng -159.775
# city_lng -159.775
# city_humidity 78
# city_clouds 88
# city_wind 1.14
# city_country CK
# City not found. Skipping...
# Processing Record 42 of set 3 | bethel
# city_lat 41.3712
# city_lng -73.414
# city_lng -73.414
# city_humidity 69
# city_clouds 20
# city_wind 6.91
# city_country US
# City not found. Skipping...
# Processing Record 43 of set 3 | paidha
# city_lat 2.4167
# city_lng 30.9855
# city_lng 30.9855
# city_humidity 32
# city_clouds 70
# city_wind 7.45
# city_country UG
# City not found. Skipping...
# Processing Record 44 of set 3 | atasu
# city_lat 48.6814
# city_lng 71.6433
# city_lng 71.6433
# city_humidity 96
# city_clouds 88
# city_wind 6.08
# city_country KZ
# City not found. Skipping...
# Processing Record 45 of set 3 | balimo
# City not found. Skipping...
# Processing Record 46 of set 3 | rongcheng
# city_lat 30.634
# city_lng 117.8517
# city_lng 117.8517
# city_humidity 50
# city_clouds 63
# city_wind 3.47
# city_country CN
# City not found. Skipping...
# Processing Record 47 of set 3 | poum
# city_lat -20.2333
# city_lng 164.0167
# city_lng 164.0167
# city_humidity 81
# city_clouds 100
# city_wind 8.81
# city_country NC
# City not found. Skipping...
# Processing Record 48 of set 3 | esperance
# city_lat -33.8667
# city_lng 121.9
# city_lng 121.9
# city_humidity 38
# city_clouds 0
# city_wind 21.85
# city_country AU
# City not found. Skipping...
# Processing Record 49 of set 3 | gambo
# city_lat 4.6482
# city_lng 22.2633
# city_lng 22.2633
# city_humidity 33
# city_clouds 31
# city_wind 2.75
# city_country CF
# City not found. Skipping...
# Processing Record 50 of set 3 | fort nelson
# city_lat 58.8053
# city_lng -122.7002
# city_lng -122.7002
# city_humidity 85
# city_clouds 90
# city_wind 0.94
# city_country CA
# City not found. Skipping...
# Processing Record 1 of set 4 | high level
# city_lat 58.5169
# city_lng -117.136
# city_lng -117.136
# city_humidity 100
# city_clouds 90
# city_wind 4.27
# city_country CA
# City not found. Skipping...
# Processing Record 2 of set 4 | yanan
# City not found. Skipping...
# Processing Record 3 of set 4 | genhe
# city_lat 50.7833
# city_lng 121.5167
# city_lng 121.5167
# city_humidity 81
# city_clouds 100
# city_wind 5.57
# city_country CN
# City not found. Skipping...
# Processing Record 4 of set 4 | erenhot
# city_lat 43.6475
# city_lng 111.9767
# city_lng 111.9767
# city_humidity 88
# city_clouds 67
# city_wind 16.15
# city_country CN
# City not found. Skipping...
# Processing Record 5 of set 4 | sanming
# city_lat 26.2486
# city_lng 117.6186
# city_lng 117.6186
# city_humidity 52
# city_clouds 100
# city_wind 5.99
# city_country CN
# City not found. Skipping...
# Processing Record 6 of set 4 | east london
# city_lat -33.0153
# city_lng 27.9116
# city_lng 27.9116
# city_humidity 60
# city_clouds 0
# city_wind 20.71
# city_country ZA
# City not found. Skipping...
# Processing Record 7 of set 4 | krasnoselkup
# city_lat 65.7
# city_lng 82.4667
# city_lng 82.4667
# city_humidity 89
# city_clouds 100
# city_wind 23
# city_country RU
# City not found. Skipping...
# Processing Record 8 of set 4 | hambantota
# city_lat 6.1241
# city_lng 81.1185
# city_lng 81.1185
# city_humidity 74
# city_clouds 40
# city_wind 10.36
# city_country LK
# City not found. Skipping...
# Processing Record 9 of set 4 | yirol
# City not found. Skipping...
# Processing Record 10 of set 4 | san andres
# city_lat 12.5847
# city_lng -81.7006
# city_lng -81.7006
# city_humidity 78
# city_clouds 40
# city_wind 8.05
# city_country CO
# City not found. Skipping...
# Processing Record 11 of set 4 | belushya guba
# City not found. Skipping...
# Processing Record 12 of set 4 | kholodnyy
# city_lat 62.7167
# city_lng 147.95
# city_lng 147.95
# city_humidity 78
# city_clouds 65
# city_wind 3.69
# city_country RU
# City not found. Skipping...
# Processing Record 13 of set 4 | dunhua
# city_lat 43.3725
# city_lng 128.2425
# city_lng 128.2425
# city_humidity 87
# city_clouds 100
# city_wind 9.6
# city_country CN
# City not found. Skipping...
# Processing Record 14 of set 4 | ca mau
# city_lat 9.1769
# city_lng 105.15
# city_lng 105.15
# city_humidity 42
# city_clouds 8
# city_wind 8.37
# city_country VN
# City not found. Skipping...
# Processing Record 15 of set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of set 4 | avera
# city_lat 33.194
# city_lng -82.5271
# city_lng -82.5271
# city_humidity 100
# city_clouds 1
# city_wind 5.1
# city_country US
# City not found. Skipping...
# Processing Record 17 of set 4 | warren
# city_lat 39.4334
# city_lng -84.1666
# city_lng -84.1666
# city_humidity 86
# city_clouds 90
# city_wind 9.22
# city_country US
# City not found. Skipping...
# Processing Record 18 of set 4 | pressbaum
# city_lat 48.176
# city_lng 16.0477
# city_lng 16.0477
# city_humidity 59
# city_clouds 75
# city_wind 11.5
# city_country AT
# City not found. Skipping...
# Processing Record 19 of set 4 | mogok
# city_lat 22.9167
# city_lng 96.5
# city_lng 96.5
# city_humidity 38
# city_clouds 7
# city_wind 1.57
# city_country MM
# City not found. Skipping...
# Processing Record 20 of set 4 | fortuna
# city_lat 40.5982
# city_lng -124.1573
# city_lng -124.1573
# city_humidity 100
# city_clouds 1
# city_wind 8.05
# city_country US
# City not found. Skipping...
# Processing Record 21 of set 4 | chokurdakh
# city_lat 70.6333
# city_lng 147.9167
# city_lng 147.9167
# city_humidity 88
# city_clouds 100
# city_wind 11.16
# city_country RU
# City not found. Skipping...
# Processing Record 22 of set 4 | bargal
# City not found. Skipping...
# Processing Record 23 of set 4 | saint-philippe
# city_lat -21.3585
# city_lng 55.7679
# city_lng 55.7679
# city_humidity 62
# city_clouds 0
# city_wind 8.05
# city_country RE
# City not found. Skipping...
# Processing Record 24 of set 4 | sungurlu
# city_lat 40.1675
# city_lng 34.3739
# city_lng 34.3739
# city_humidity 88
# city_clouds 100
# city_wind 4.5
# city_country TR
# City not found. Skipping...
# Processing Record 25 of set 4 | leirvik
# city_lat 59.7798
# city_lng 5.5005
# city_lng 5.5005
# city_humidity 93
# city_clouds 90
# city_wind 25.32
# city_country NO
# City not found. Skipping...
# Processing Record 26 of set 4 | oro valley
# city_lat 32.3909
# city_lng -110.9665
# city_lng -110.9665
# city_humidity 23
# city_clouds 34
# city_wind 4
# city_country US
# City not found. Skipping...
# Processing Record 27 of set 4 | lakatoro
# city_lat -16.0999
# city_lng 167.4164
# city_lng 167.4164
# city_humidity 73
# city_clouds 50
# city_wind 4.12
# city_country VU
# City not found. Skipping...
# Processing Record 28 of set 4 | severo-kurilsk
# city_lat 50.6789
# city_lng 156.125
# city_lng 156.125
# city_humidity 97
# city_clouds 85
# city_wind 21.45
# city_country RU
# City not found. Skipping...
# Processing Record 29 of set 4 | qaanaaq
# city_lat 77.484
# city_lng -69.3632
# city_lng -69.3632
# city_humidity 83
# city_clouds 0
# city_wind 4.52
# city_country GL
# City not found. Skipping...
# Processing Record 30 of set 4 | sola
# city_lat -13.8833
# city_lng 167.55
# city_lng 167.55
# city_humidity 74
# city_clouds 20
# city_wind 10.76
# city_country VU
# City not found. Skipping...
# Processing Record 31 of set 4 | tasiilaq
# city_lat 65.6145
# city_lng -37.6368
# city_lng -37.6368
# city_humidity 93
# city_clouds 75
# city_wind 5.55
# city_country GL
# City not found. Skipping...
# Processing Record 32 of set 4 | cabo san lucas
# city_lat 22.8909
# city_lng -109.9124
# city_lng -109.9124
# city_humidity 65
# city_clouds 0
# city_wind 8.28
# city_country MX
# City not found. Skipping...
# Processing Record 33 of set 4 | samusu
# City not found. Skipping...
# Processing Record 34 of set 4 | san quintin
# city_lat 30.4833
# city_lng -115.95
# city_lng -115.95
# city_humidity 41
# city_clouds 0
# city_wind 1.81
# city_country MX
# City not found. Skipping...
# Processing Record 35 of set 4 | mount gambier
# city_lat -37.8333
# city_lng 140.7667
# city_lng 140.7667
# city_humidity 45
# city_clouds 0
# city_wind 14.97
# city_country AU
# City not found. Skipping...
# Processing Record 36 of set 4 | lolua
# City not found. Skipping...
# Processing Record 37 of set 4 | ahipara
# city_lat -35.1667
# city_lng 173.1667
# city_lng 173.1667
# city_humidity 86
# city_clouds 47
# city_wind 8.5
# city_country NZ
# City not found. Skipping...
# Processing Record 38 of set 4 | alofi
# city_lat -19.0595
# city_lng -169.9187
# city_lng -169.9187
# city_humidity 83
# city_clouds 100
# city_wind 4.61
# city_country NU
# City not found. Skipping...
# Processing Record 39 of set 4 | georgetown
# city_lat 5.4112
# city_lng 100.3354
# city_lng 100.3354
# city_humidity 70
# city_clouds 20
# city_wind 9.22
# city_country MY
# City not found. Skipping...
# Processing Record 40 of set 4 | hamilton
# city_lat 39.1834
# city_lng -84.5333
# city_lng -84.5333
# city_humidity 86
# city_clouds 90
# city_wind 12.66
# city_country US
# City not found. Skipping...
# Processing Record 41 of set 4 | labuan
# city_lat 5.2767
# city_lng 115.2417
# city_lng 115.2417
# city_humidity 94
# city_clouds 40
# city_wind 2.3
# city_country MY
# City not found. Skipping...
# Processing Record 42 of set 4 | arman
# city_lat 59.7
# city_lng 150.1667
# city_lng 150.1667
# city_humidity 86
# city_clouds 100
# city_wind 13.56
# city_country RU
# City not found. Skipping...
# Processing Record 43 of set 4 | pindi gheb
# city_lat 33.2402
# city_lng 72.2661
# city_lng 72.2661
# city_humidity 25
# city_clouds 0
# city_wind 3.98
# city_country PK
# City not found. Skipping...
# Processing Record 44 of set 4 | portland
# city_lat 45.5234
# city_lng -122.6762
# city_lng -122.6762
# city_humidity 90
# city_clouds 100
# city_wind 1.16
# city_country US
# City not found. Skipping...
# Processing Record 45 of set 4 | calabozo
# city_lat 8.9242
# city_lng -67.4293
# city_lng -67.4293
# city_humidity 71
# city_clouds 89
# city_wind 7.67
# city_country VE
# City not found. Skipping...
# Processing Record 46 of set 4 | grindavik
# city_lat 63.8424
# city_lng -22.4338
# city_lng -22.4338
# city_humidity 75
# city_clouds 75
# city_wind 11.5
# city_country IS
# City not found. Skipping...
# Processing Record 47 of set 4 | sept-iles
# city_lat 50.2001
# city_lng -66.3821
# city_lng -66.3821
# city_humidity 93
# city_clouds 100
# city_wind 14.97
# city_country CA
# City not found. Skipping...
# Processing Record 48 of set 4 | bardiyah
# city_lat 31.7561
# city_lng 25.0865
# city_lng 25.0865
# city_humidity 71
# city_clouds 26
# city_wind 18.01
# city_country LY
# City not found. Skipping...
# Processing Record 49 of set 4 | emba
# city_lat 48.8264
# city_lng 58.1442
# city_lng 58.1442
# city_humidity 94
# city_clouds 0
# city_wind 7.09
# city_country KZ
# City not found. Skipping...
# Processing Record 50 of set 4 | port macquarie
# city_lat -31.4333
# city_lng 152.9167
# city_lng 152.9167
# city_humidity 59
# city_clouds 72
# city_wind 1.99
# city_country AU
# City not found. Skipping...
# Processing Record 1 of set 5 | kudahuvadhoo
# city_lat 2.6708
# city_lng 72.8944
# city_lng 72.8944
# city_humidity 70
# city_clouds 0
# city_wind 5.28
# city_country MV
# City not found. Skipping...
# Processing Record 2 of set 5 | aksu
# city_lat 41.1231
# city_lng 80.2644
# city_lng 80.2644
# city_humidity 75
# city_clouds 0
# city_wind 1.74
# city_country CN
# City not found. Skipping...
# Processing Record 3 of set 5 | lunca ilvei
# city_lat 47.3667
# city_lng 24.9833
# city_lng 24.9833
# city_humidity 88
# city_clouds 85
# city_wind 1.45
# city_country RO
# City not found. Skipping...
# Processing Record 4 of set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of set 5 | saldanha
# city_lat -33.0117
# city_lng 17.9442
# city_lng 17.9442
# city_humidity 88
# city_clouds 0
# city_wind 3.44
# city_country ZA
# City not found. Skipping...
# Processing Record 6 of set 5 | lagoa
# city_lat 39.05
# city_lng -27.9833
# city_lng -27.9833
# city_humidity 89
# city_clouds 100
# city_wind 24.07
# city_country PT
# City not found. Skipping...
# Processing Record 7 of set 5 | palagonia
# city_lat 37.3283
# city_lng 14.7448
# city_lng 14.7448
# city_humidity 100
# city_clouds 0
# city_wind 8.05
# city_country IT
# City not found. Skipping...
# Processing Record 8 of set 5 | takoradi
# city_lat 4.8845
# city_lng -1.7554
# city_lng -1.7554
# city_humidity 85
# city_clouds 21
# city_wind 2.95
# city_country GH
# City not found. Skipping...
# Processing Record 9 of set 5 | damaturu
# city_lat 11.747
# city_lng 11.9608
# city_lng 11.9608
# city_humidity 23
# city_clouds 0
# city_wind 8.21
# city_country NG
# City not found. Skipping...
# Processing Record 10 of set 5 | vagur
# city_lat 61.4732
# city_lng -6.8119
# city_lng -6.8119
# city_humidity 86
# city_clouds 100
# city_wind 37.65
# city_country FO
# City not found. Skipping...
# Processing Record 11 of set 5 | pilibanga
# city_lat 29.4916
# city_lng 74.079
# city_lng 74.079
# city_humidity 22
# city_clouds 0
# city_wind 9.22
# city_country IN
# City not found. Skipping...
# Processing Record 12 of set 5 | utiroa
# City not found. Skipping...
# Processing Record 13 of set 5 | college
# city_lat 64.8569
# city_lng -147.8028
# city_lng -147.8028
# city_humidity 71
# city_clouds 75
# city_wind 4.47
# city_country US
# City not found. Skipping...
# Processing Record 14 of set 5 | hohhot
# city_lat 40.8106
# city_lng 111.6522
# city_lng 111.6522
# city_humidity 45
# city_clouds 0
# city_wind 4.47
# city_country CN
# City not found. Skipping...
# Processing Record 15 of set 5 | dali
# city_lat 25.7
# city_lng 100.1833
# city_lng 100.1833
# city_humidity 67
# city_clouds 98
# city_wind 5.21
# city_country CN
# City not found. Skipping...
# Processing Record 16 of set 5 | santa cruz
# city_lat -17.8
# city_lng -63.1667
# city_lng -63.1667
# city_humidity 94
# city_clouds 75
# city_wind 12.66
# city_country BO
# City not found. Skipping...
# Processing Record 17 of set 5 | liverpool
# city_lat 53.4106
# city_lng -2.9779
# city_lng -2.9779
# city_humidity 81
# city_clouds 20
# city_wind 13.8
# city_country GB
# City not found. Skipping...
# Processing Record 18 of set 5 | mackenzie
# city_lat 55.2999
# city_lng -123.1698
# city_lng -123.1698
# city_humidity 93
# city_clouds 90
# city_wind 6.91
# city_country CA
# City not found. Skipping...
# Processing Record 19 of set 5 | husavik
# city_lat 66.0449
# city_lng -17.3389
# city_lng -17.3389
# city_humidity 100
# city_clouds 90
# city_wind 3.44
# city_country IS
# City not found. Skipping...
# Processing Record 20 of set 5 | gewane
# city_lat 10.1664
# city_lng 40.6453
# city_lng 40.6453
# city_humidity 26
# city_clouds 100
# city_wind 4.65
# city_country ET
# City not found. Skipping...
# Processing Record 21 of set 5 | premnitz
# city_lat 52.5333
# city_lng 12.3333
# city_lng 12.3333
# city_humidity 80
# city_clouds 100
# city_wind 3.11
# city_country DE
# City not found. Skipping...
# Processing Record 22 of set 5 | warqla
# City not found. Skipping...
# Processing Record 23 of set 5 | petropavlovka
# city_lat 50.6114
# city_lng 105.3196
# city_lng 105.3196
# city_humidity 85
# city_clouds 0
# city_wind 3.69
# city_country RU
# City not found. Skipping...
# Processing Record 24 of set 5 | thompson
# city_lat 55.7435
# city_lng -97.8558
# city_lng -97.8558
# city_humidity 84
# city_clouds 1
# city_wind 9.22
# city_country CA
# City not found. Skipping...
# Processing Record 25 of set 5 | tiznit
# City not found. Skipping...
# Processing Record 26 of set 5 | fairbanks
# City not found. Skipping...
# Processing Record 27 of set 5 | nusaybin
# City not found. Skipping...
# Processing Record 28 of set 5 | port blair
# City not found. Skipping...
# Processing Record 29 of set 5 | dipkarpaz
# City not found. Skipping...
# Processing Record 30 of set 5 | yellowknife
# City not found. Skipping...
# Processing Record 31 of set 5 | abnub
# City not found. Skipping...
# Processing Record 32 of set 5 | vestmanna
# City not found. Skipping...
# Processing Record 33 of set 5 | karla
# City not found. Skipping...
# Processing Record 34 of set 5 | mahibadhoo
# City not found. Skipping...
# Processing Record 35 of set 5 | jaru
# City not found. Skipping...
# Processing Record 36 of set 5 | colombia
# City not found. Skipping...
# Processing Record 37 of set 5 | marsh harbour
# City not found. Skipping...
# Processing Record 38 of set 5 | coquimbo
# City not found. Skipping...
# Processing Record 39 of set 5 | olafsvik
# City not found. Skipping...
# Processing Record 40 of set 5 | nongan
# City not found. Skipping...
# Processing Record 41 of set 5 | sorvag
# City not found. Skipping...
# Processing Record 42 of set 5 | isangel
# City not found. Skipping...
# Processing Record 43 of set 5 | simpang
# City not found. Skipping...
# Processing Record 44 of set 5 | naze
# City not found. Skipping...
# Processing Record 45 of set 5 | correia pinto
# City not found. Skipping...
# Processing Record 46 of set 5 | coari
# City not found. Skipping...
# Processing Record 47 of set 5 | sharjah
# City not found. Skipping...
# Processing Record 48 of set 5 | port elizabeth
# City not found. Skipping...
# Processing Record 49 of set 5 | qeshm
# City not found. Skipping...
# Processing Record 50 of set 5 | new norfolk
# City not found. Skipping...
# Processing Record 1 of set 6 | whitecourt
# City not found. Skipping...
# Processing Record 2 of set 6 | bambous virieux
# City not found. Skipping...
# Processing Record 3 of set 6 | beyneu
# City not found. Skipping...
# Processing Record 4 of set 6 | gayny
# City not found. Skipping...
# Processing Record 5 of set 6 | pedasi
# City not found. Skipping...
# Processing Record 6 of set 6 | chuy
# City not found. Skipping...
# Processing Record 7 of set 6 | upata
# City not found. Skipping...
# Processing Record 8 of set 6 | les cayes
# City not found. Skipping...
# Processing Record 9 of set 6 | horsham
# City not found. Skipping...
# Processing Record 10 of set 6 | sinjah
# City not found. Skipping...
# Processing Record 11 of set 6 | abu dhabi
# City not found. Skipping...
# Processing Record 12 of set 6 | puerto del rosario
# City not found. Skipping...
# Processing Record 13 of set 6 | qui nhon
# City not found. Skipping...
# Processing Record 14 of set 6 | kavieng
# City not found. Skipping...
# Processing Record 15 of set 6 | marcona
# City not found. Skipping...
# Processing Record 16 of set 6 | fiesole
# City not found. Skipping...
# Processing Record 17 of set 6 | sao joao da barra
# City not found. Skipping...
# Processing Record 18 of set 6 | belyy yar
# City not found. Skipping...
# Processing Record 19 of set 6 | carlton
# City not found. Skipping...
# Processing Record 20 of set 6 | porbandar
# City not found. Skipping...
# Processing Record 21 of set 6 | ngukurr
# City not found. Skipping...
# Processing Record 22 of set 6 | mar del plata
# City not found. Skipping...
# Processing Record 23 of set 6 | quatre cocos
# City not found. Skipping...
# Processing Record 24 of set 6 | cabo frio
# City not found. Skipping...
# Processing Record 25 of set 6 | morros
# City not found. Skipping...
# Processing Record 26 of set 6 | bilma
# City not found. Skipping...
# Processing Record 27 of set 6 | mwene-ditu
# City not found. Skipping...
# Processing Record 28 of set 6 | ambunti
# City not found. Skipping...
# Processing Record 29 of set 6 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 30 of set 6 | derzhavinsk
# City not found. Skipping...
# Processing Record 31 of set 6 | grand river south east
# City not found. Skipping...
# Processing Record 32 of set 6 | belaya gora
# City not found. Skipping...
# Processing Record 33 of set 6 | kikwit
# City not found. Skipping...
# Processing Record 34 of set 6 | aklavik
# City not found. Skipping...
# Processing Record 35 of set 6 | santa rosa
# City not found. Skipping...
# Processing Record 36 of set 6 | rio gallegos
# City not found. Skipping...
# Processing Record 37 of set 6 | ocozocoautla
# City not found. Skipping...
# Processing Record 38 of set 6 | geraldton
# City not found. Skipping...
# Processing Record 39 of set 6 | kyren
# City not found. Skipping...
# Processing Record 40 of set 6 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 41 of set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of set 6 | svetlogorsk
# City not found. Skipping...
# Processing Record 43 of set 6 | aswan
# City not found. Skipping...
# Processing Record 44 of set 6 | ilhabela
# City not found. Skipping...
# Processing Record 45 of set 6 | mackay
# City not found. Skipping...
# Processing Record 46 of set 6 | port-gentil
# City not found. Skipping...
# Processing Record 47 of set 6 | goderich
# City not found. Skipping...
# Processing Record 48 of set 6 | guerrero negro
# City not found. Skipping...
# Processing Record 49 of set 6 | moshi
# City not found. Skipping...
# Processing Record 50 of set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of set 7 | cabedelo
# City not found. Skipping...
# Processing Record 2 of set 7 | tharad
# City not found. Skipping...
# Processing Record 3 of set 7 | korla
# City not found. Skipping...
# Processing Record 4 of set 7 | luena
# City not found. Skipping...
# Processing Record 5 of set 7 | ancud
# City not found. Skipping...
# Processing Record 6 of set 7 | bo phloi
# City not found. Skipping...
# Processing Record 7 of set 7 | sorland
# City not found. Skipping...
# Processing Record 8 of set 7 | dwarahat
# City not found. Skipping...
# Processing Record 9 of set 7 | kasongo
# City not found. Skipping...
# Processing Record 10 of set 7 | chapais
# City not found. Skipping...
# Processing Record 11 of set 7 | sur
# City not found. Skipping...
# Processing Record 12 of set 7 | caravelas
# City not found. Skipping...
# Processing Record 13 of set 7 | ituni
# City not found. Skipping...
# Processing Record 14 of set 7 | viesca
# City not found. Skipping...
# Processing Record 15 of set 7 | jinchang
# City not found. Skipping...
# Processing Record 16 of set 7 | rungata
# City not found. Skipping...
# Processing Record 17 of set 7 | pingzhuang
# City not found. Skipping...
# Processing Record 18 of set 7 | katsuura
# City not found. Skipping...
# Processing Record 19 of set 7 | deer lake
# City not found. Skipping...
# Processing Record 20 of set 7 | kruisfontein
# City not found. Skipping...
# Processing Record 21 of set 7 | macau
# City not found. Skipping...
# Processing Record 22 of set 7 | namatanai
# City not found. Skipping...
# Processing Record 23 of set 7 | tutoia
# City not found. Skipping...
# Processing Record 24 of set 7 | kuryk
# City not found. Skipping...
# Processing Record 25 of set 7 | qasigiannguit
# City not found. Skipping...
# Processing Record 26 of set 7 | buldana
# City not found. Skipping...
# Processing Record 27 of set 7 | cassilandia
# City not found. Skipping...
# Processing Record 28 of set 7 | soteapan
# City not found. Skipping...
# Processing Record 29 of set 7 | half moon bay
# City not found. Skipping...
# Processing Record 30 of set 7 | karakol
# City not found. Skipping...
# Processing Record 31 of set 7 | balaka
# City not found. Skipping...
# Processing Record 32 of set 7 | statesboro
# City not found. Skipping...
# Processing Record 33 of set 7 | ilmajoki
# City not found. Skipping...
# Processing Record 34 of set 7 | nueva loja
# City not found. Skipping...
# Processing Record 35 of set 7 | noumea
# City not found. Skipping...
# Processing Record 36 of set 7 | sobolevo
# City not found. Skipping...
# Processing Record 37 of set 7 | chemal
# City not found. Skipping...
# Processing Record 38 of set 7 | ende
# City not found. Skipping...
# Processing Record 39 of set 7 | birao
# City not found. Skipping...
# Processing Record 40 of set 7 | iracoubo
# City not found. Skipping...
# Processing Record 41 of set 7 | thabazimbi
# City not found. Skipping...
# Processing Record 42 of set 7 | vardo
# City not found. Skipping...
# Processing Record 43 of set 7 | mulchen
# City not found. Skipping...
# Processing Record 44 of set 7 | longhua
# City not found. Skipping...
# Processing Record 45 of set 7 | beni
# City not found. Skipping...
# Processing Record 46 of set 7 | mahajanga
# City not found. Skipping...
# Processing Record 47 of set 7 | beringovskiy
# City not found. Skipping...
# Processing Record 48 of set 7 | ginda
# City not found. Skipping...
# Processing Record 49 of set 7 | makakilo city
# City not found. Skipping...
# Processing Record 50 of set 7 | vila franca do campo
# City not found. Skipping...
# Processing Record 1 of set 8 | dehloran
# City not found. Skipping...
# Processing Record 2 of set 8 | tuatapere
# City not found. Skipping...
# Processing Record 3 of set 8 | kutum
# City not found. Skipping...
# Processing Record 4 of set 8 | laguna
# City not found. Skipping...
# Processing Record 5 of set 8 | la union
# City not found. Skipping...
# Processing Record 6 of set 8 | puerto colombia
# City not found. Skipping...
# Processing Record 7 of set 8 | china
# City not found. Skipping...
# Processing Record 8 of set 8 | saint-joseph
# City not found. Skipping...
# Processing Record 9 of set 8 | tolmachevo
# City not found. Skipping...
# ...
# Processing Record 20 of set 11 | ures
# City not found. Skipping...
# Processing Record 21 of set 11 | zambezi
# City not found. Skipping...
# Processing Record 22 of set 11 | bako
# City not found. Skipping...
# Processing Record 23 of set 11 | paamiut
# City not found. Skipping...
# Processing Record 24 of set 11 | hofn
# City not found. Skipping...
# Processing Record 25 of set 11 | nishihara
# City not found. Skipping...
# Processing Record 26 of set 11 | agadez
# City not found. Skipping...
# Processing Record 27 of set 11 | cayenne
# City not found. Skipping...
# Processing Record 28 of set 11 | asau
# City not found. Skipping...
# Processing Record 29 of set 11 | prince rupert
# City not found. Skipping...
# Processing Record 30 of set 11 | asyut
# City not found. Skipping...
# Processing Record 31 of set 11 | tautira
# City not found. Skipping...
# Processing Record 32 of set 11 | macaboboni
# City not found. Skipping...
# Processing Record 33 of set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 34 of set 11 | richmond
# City not found. Skipping...
# Processing Record 35 of set 11 | jumla
# City not found. Skipping...
# Processing Record 36 of set 11 | lorengau
# City not found. Skipping...
# Processing Record 37 of set 11 | muborak
# City not found. Skipping...
# Processing Record 38 of set 11 | iskateley
# City not found. Skipping...
# Processing Record 39 of set 11 | gwadar
# City not found. Skipping...
# Processing Record 40 of set 11 | san pedro
# City not found. Skipping...
# Processing Record 41 of set 11 | talcahuano
# City not found. Skipping...
# Processing Record 42 of set 11 | smidovich
# City not found. Skipping...
# Processing Record 43 of set 11 | rawah
# City not found. Skipping...
# Processing Record 44 of set 11 | codrington
# City not found. Skipping...
# Processing Record 45 of set 11 | tevaitoa
# City not found. Skipping...
# Processing Record 46 of set 11 | puerto el triunfo
# City not found. Skipping...
# Processing Record 47 of set 11 | ingenbohl
# City not found. Skipping...
# Processing Record 48 of set 11 | teguise
# City not found. Skipping...
# Processing Record 49 of set 11 | kabwe
# City not found. Skipping...
# Processing Record 50 of set 11 | pafos
# City not found. Skipping...
# Processing Record 1 of set 12 | bossembele
# City not found. Skipping...
# Processing Record 2 of set 12 | yining
# City not found. Skipping...
# Processing Record 3 of set 12 | finnsnes
# City not found. Skipping...
# Processing Record 4 of set 12 | abbeville
# City not found. Skipping...
# Processing Record 5 of set 12 | ambilobe
# City not found. Skipping...
# Processing Record 6 of set 12 | shamary
# City not found. Skipping...
# Processing Record 7 of set 12 | kavaratti
# City not found. Skipping...
# Processing Record 8 of set 12 | llandrindod wells
# City not found. Skipping...
# Processing Record 9 of set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of set 12 | le pont-de-claix
# City not found. Skipping...
# Processing Record 11 of set 12 | samfya
# City not found. Skipping...
# Processing Record 12 of set 12 | basi
# City not found. Skipping...
# Processing Record 13 of set 12 | gornozavodsk
# City not found. Skipping...
# Processing Record 14 of set 12 | roswell
# City not found. Skipping...
# Processing Record 15 of set 12 | kaka
# City not found. Skipping...
# Processing Record 16 of set 12 | jaguariaiva
# City not found. Skipping...
# Processing Record 17 of set 12 | kozhva
# City not found. Skipping...
# Processing Record 18 of set 12 | ilulissat
# City not found. Skipping...
# Processing Record 19 of set 12 | thinadhoo
# City not found. Skipping...
# Processing Record 20 of set 12 | coihaique
# City not found. Skipping...
# Processing Record 21 of set 12 | sao geraldo do araguaia
# City not found. Skipping...
# Processing Record 22 of set 12 | baiyin
# City not found. Skipping...
# Processing Record 23 of set 12 | spodnja idrija
# City not found. Skipping...
# Processing Record 24 of set 12 | ambam
# City not found. Skipping...
# Processing Record 25 of set 12 | majur
# City not found. Skipping...
# Processing Record 26 of set 12 | leh
# City not found. Skipping...
# Processing Record 27 of set 12 | awbari
# City not found. Skipping...
# Processing Record 28 of set 12 | jalu
# City not found. Skipping...
# Processing Record 29 of set 12 | santiago del estero
# City not found. Skipping...
# Processing Record 30 of set 12 | lerwick
# City not found. Skipping...
# Processing Record 31 of set 12 | homa bay
# City not found. Skipping...
# Processing Record 32 of set 12 | eyl
# City not found. Skipping...
# Processing Record 33 of set 12 | cukai
# City not found. Skipping...
# Processing Record 34 of set 12 | le port
# City not found. Skipping...
# Processing Record 35 of set 12 | astipalaia
# City not found. Skipping...
# Processing Record 36 of set 12 | zhigansk
# City not found. Skipping...
# Processing Record 37 of set 12 | les escoumins
# City not found. Skipping...
# Processing Record 38 of set 12 | dayong
# City not found. Skipping...
# Processing Record 39 of set 12 | kochevo
# City not found. Skipping...
# Processing Record 40 of set 12 | kerouane
# City not found. Skipping...
# Processing Record 41 of set 12 | keti bandar
# City not found. Skipping...
# Processing Record 42 of set 12 | nambour
# City not found. Skipping...
# Processing Record 43 of set 12 | atlantic city
# City not found. Skipping...
# Processing Record 44 of set 12 | maridi
# City not found. Skipping...
# Processing Record 45 of set 12 | biak
# City not found. Skipping...
# Processing Record 46 of set 12 | dolbeau
# City not found. Skipping...
# Processing Record 47 of set 12 | kharagauli
# City not found. Skipping...
# Processing Record 48 of set 12 | changping
# City not found. Skipping...
# Processing Record 49 of set 12 | turayf
# City not found. Skipping...
# Processing Record 50 of set 12 | houston
# City not found. Skipping...
# Processing Record 1 of set 13 | ust-kuyga
# City not found. Skipping...
# Processing Record 2 of set 13 | kegayli
# City not found. Skipping...
# Processing Record 3 of set 13 | qarqin
# City not found. Skipping...
# Processing Record 4 of set 13 | hay river
# City not found. Skipping...
# Processing Record 5 of set 13 | gannan
# City not found. Skipping...
# Processing Record 6 of set 13 | shingu
# City not found. Skipping...
# Processing Record 7 of set 13 | raudeberg
# City not found. Skipping...
# Processing Record 8 of set 13 | abiy adi
# City not found. Skipping...
# Processing Record 9 of set 13 | saleaula
# City not found. Skipping...
# Processing Record 10 of set 13 | tshela
# City not found. Skipping...
# Processing Record 11 of set 13 | lavrentiya
# City not found. Skipping...
# Processing Record 12 of set 13 | dongsheng
# City not found. Skipping...
# Processing Record 13 of set 13 | otradnoye
# City not found. Skipping...
# Processing Record 14 of set 13 | solwezi
# City not found. Skipping...
# Processing Record 15 of set 13 | norsup
# City not found. Skipping...
# Processing Record 16 of set 13 | mulege
# City not found. Skipping...
# Processing Record 17 of set 13 | haibowan
# City not found. Skipping...
# Processing Record 18 of set 13 | bonavista
# City not found. Skipping...
# Processing Record 19 of set 13 | tullahoma
# City not found. Skipping...
# Processing Record 20 of set 13 | nynashamn
# City not found. Skipping...
# Processing Record 21 of set 13 | lasa
# City not found. Skipping...
# Processing Record 22 of set 13 | broome
# City not found. Skipping...
# Processing Record 23 of set 13 | nyurba
# City not found. Skipping...
# Processing Record 24 of set 13 | barentu
# City not found. Skipping...
# Processing Record 25 of set 13 | nouakchott
# City not found. Skipping...
# Processing Record 26 of set 13 | enid
# City not found. Skipping...
# Processing Record 27 of set 13 | pedernales
# City not found. Skipping...
# Processing Record 28 of set 13 | sterling
# City not found. Skipping...
# Processing Record 29 of set 13 | riyadh
# City not found. Skipping...
# Processing Record 30 of set 13 | vrede
# City not found. Skipping...
# Processing Record 31 of set 13 | tucuma
# City not found. Skipping...
# Processing Record 32 of set 13 | dzaoudzi
# City not found. Skipping...
# Processing Record 33 of set 13 | fairview
# City not found. Skipping...
# Processing Record 34 of set 13 | poronaysk
# City not found. Skipping...
# Processing Record 35 of set 13 | iberia
# City not found. Skipping...
# Processing Record 36 of set 13 | leshukonskoye
# City not found. Skipping...
# Processing Record 37 of set 13 | inta
# City not found. Skipping...
# Processing Record 38 of set 13 | ottawa
# City not found. Skipping...
# Processing Record 39 of set 13 | bokspits
# City not found. Skipping...
# Processing Record 40 of set 13 | denpasar
# City not found. Skipping...
# Processing Record 41 of set 13 | riyaq
# City not found. Skipping...
# Processing Record 42 of set 13 | darhan
# City not found. Skipping...
# Processing Record 43 of set 13 | katangli
# City not found. Skipping...
# Processing Record 44 of set 13 | sabanalarga
# City not found. Skipping...
# Processing Record 45 of set 13 | porosozero
# City not found. Skipping...
# Processing Record 46 of set 13 | santiago de cao
# City not found. Skipping...
# Processing Record 47 of set 13 | dracena
# City not found. Skipping...
# Processing Record 48 of set 13 | west wendover
# City not found. Skipping...
# Processing Record 49 of set 13 | basoko
# City not found. Skipping...
# Processing Record 50 of set 13 | talnakh
# City not found. Skipping...
# Processing Record 1 of set 14 | benjamin constant
# City not found. Skipping...
# Processing Record 2 of set 14 | gold coast
# City not found. Skipping...
# Processing Record 3 of set 14 | kushima
# City not found. Skipping...
# Processing Record 4 of set 14 | pucallpa
# City not found. Skipping...
# Processing Record 5 of set 14 | hit
# City not found. Skipping...
# Processing Record 6 of set 14 | penzance
# City not found. Skipping...
# Processing Record 7 of set 14 | muyezerskiy
# City not found. Skipping...
# Processing Record 8 of set 14 | rocha
# City not found. Skipping...
# Processing Record 9 of set 14 | lufilufi
# City not found. Skipping...
# Processing Record 10 of set 14 | zheleznodorozhnyy
# City not found. Skipping...
# Processing Record 11 of set 14 | batticaloa
# City not found. Skipping...
# Processing Record 12 of set 14 | lompoc
# City not found. Skipping...
# Processing Record 13 of set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of set 14 | flinders
# City not found. Skipping...
# Processing Record 15 of set 14 | sibolga
# City not found. Skipping...
# Processing Record 16 of set 14 | nagorsk
# City not found. Skipping...
# Processing Record 17 of set 14 | hihifo
# City not found. Skipping...
# Processing Record 18 of set 14 | lieksa
# City not found. Skipping...
# Processing Record 19 of set 14 | nanakuli
# City not found. Skipping...
# Processing Record 20 of set 14 | carballo
# City not found. Skipping...
# Processing Record 21 of set 14 | uvalde
# City not found. Skipping...
# Processing Record 22 of set 14 | la ronge
# City not found. Skipping...
# Processing Record 23 of set 14 | kenai
# City not found. Skipping...
# Processing Record 24 of set 14 | reshetnikovo
# City not found. Skipping...
# Processing Record 25 of set 14 | hanko
# City not found. Skipping...
# Processing Record 26 of set 14 | san jose
# City not found. Skipping...
# Processing Record 27 of set 14 | pandaria
# City not found. Skipping...
# Processing Record 28 of set 14 | faya
# City not found. Skipping...
# Processing Record 29 of set 14 | ouango
# City not found. Skipping...
# Processing Record 30 of set 14 | aktau
# City not found. Skipping...
# Processing Record 31 of set 14 | doka
# City not found. Skipping...
# Processing Record 32 of set 14 | larap
# City not found. Skipping...
# Processing Record 33 of set 14 | sidney
# City not found. Skipping...
# Processing Record 34 of set 14 | mareeba
# City not found. Skipping...
# Processing Record 35 of set 14 | pilar
# City not found. Skipping...
# Processing Record 36 of set 14 | nadvoitsy
# City not found. Skipping...
# Processing Record 37 of set 14 | ankazoabo
# City not found. Skipping...
# Processing Record 38 of set 14 | guanay
# City not found. Skipping...
# Processing Record 39 of set 14 | brae
# City not found. Skipping...
# Processing Record 40 of set 14 | bongandanga
# City not found. Skipping...
# Processing Record 41 of set 14 | zemetchino
# City not found. Skipping...
# Processing Record 42 of set 14 | bonthe
# City not found. Skipping...
# Processing Record 43 of set 14 | colares
# City not found. Skipping...
# Processing Record 44 of set 14 | kasur
# City not found. Skipping...
# Processing Record 45 of set 14 | mrakovo
# City not found. Skipping...
# Processing Record 46 of set 14 | padang
# City not found. Skipping...
# Processing Record 47 of set 14 | magistralnyy
# City not found. Skipping...
# Processing Record 48 of set 14 | gataivai
# City not found. Skipping...
# Processing Record 49 of set 14 | la asuncion
# City not found. Skipping...
# Processing Record 50 of set 14 | haimen
# City not found. Skipping...
# Processing Record 1 of set 15 | contai
# City not found. Skipping...
# Processing Record 2 of set 15 | bongor
# City not found. Skipping...
# Processing Record 3 of set 15 | jurmala
# City not found. Skipping...
# Processing Record 4 of set 15 | raul soares
# City not found. Skipping...
# Processing Record 5 of set 15 | dien bien
# City not found. Skipping...
# Processing Record 6 of set 15 | labutta
# City not found. Skipping...
# Processing Record 7 of set 15 | tabiauea
# City not found. Skipping...
# Processing Record 8 of set 15 | wilkie
# City not found. Skipping...
# Processing Record 9 of set 15 | muros
# City not found. Skipping...
# Processing Record 10 of set 15 | homer
# City not found. Skipping...
# Processing Record 11 of set 15 | baykit
# City not found. Skipping...
# Processing Record 12 of set 15 | charters towers
# City not found. Skipping...
# Processing Record 13 of set 15 | verkh-usugli
# City not found. Skipping...
# Processing Record 14 of set 15 | amapa
# City not found. Skipping...
# Processing Record 15 of set 15 | kosh-agach
# City not found. Skipping...
# Processing Record 16 of set 15 | north bend
# City not found. Skipping...
# Processing Record 17 of set 15 | flin flon
# City not found. Skipping...
# Processing Record 18 of set 15 | mehamn
# City not found. Skipping...
# Processing Record 19 of set 15 | lima
# City not found. Skipping...
# Processing Record 20 of set 15 | virginia beach
# City not found. Skipping...
# Processing Record 21 of set 15 | magadan
# City not found. Skipping...
# Processing Record 22 of set 15 | mountain home
# City not found. Skipping...
# Processing Record 23 of set 15 | mercedes
# City not found. Skipping...
# Processing Record 24 of set 15 | patacamaya
# City not found. Skipping...
# Processing Record 25 of set 15 | saquarema
# City not found. Skipping...
# Processing Record 26 of set 15 | mildura
# City not found. Skipping...
# Processing Record 27 of set 15 | banda aceh
# City not found. Skipping...
# Processing Record 28 of set 15 | chumikan
# City not found. Skipping...
# Processing Record 29 of set 15 | prince albert
# City not found. Skipping...
# Processing Record 30 of set 15 | kracheh
# City not found. Skipping...
# Processing Record 31 of set 15 | durban
# City not found. Skipping...
# Processing Record 32 of set 15 | prainha
# City not found. Skipping...
# Processing Record 33 of set 15 | uni
# City not found. Skipping...
# Processing Record 34 of set 15 | uyemskiy
# City not found. Skipping...
# Processing Record 35 of set 15 | yuryevets
# City not found. Skipping...
# Processing Record 36 of set 15 | mahina
# City not found. Skipping...
# Processing Record 37 of set 15 | amalapuram
# City not found. Skipping...
# Processing Record 38 of set 15 | oriximina
# City not found. Skipping...
# Processing Record 39 of set 15 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 40 of set 15 | pachino
# City not found. Skipping...
# Processing Record 41 of set 15 | shambu
# City not found. Skipping...
# Processing Record 42 of set 15 | miyazu
# City not found. Skipping...
# Processing Record 43 of set 15 | estelle
# City not found. Skipping...
# Processing Record 44 of set 15 | acapulco
# City not found. Skipping...
# Processing Record 45 of set 15 | dhidhdhoo
# City not found. Skipping...
# Processing Record 46 of set 15 | craig
# City not found. Skipping...
# Processing Record 47 of set 15 | jaciara
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 0

# %%
print(cities)
# Out:
# ['darnah', 'ushuaia', 'butaritari', 'smithers', 'nha trang', 'pacific grove', 'carbonia', 'ponta do sol', 'rayevskiy', 'ribeira grande', 'nouadhibou', 'namibe', 'hilo', 'atuona', 'tulare', 'rikitea', 'bairiki', 'carnarvon', 'saskylakh', 'cockburn town', 'lebu', 'kodiak', 'hobart', 'punta arenas', 'richards bay', 'port alfred', 'sitka', 'nuuk', 'antsohihy', 'hermanus', 'airai', 'pevek', 'cidreira', 'wulanhaote', 'apac', 'svetlaya', 'busselton', 'palabuhanratu', 'cochrane', 'chernyy yar', 'nikolskoye', 'odweyne', 'nome', 'visconde do rio branco', 'halalo', 'albany', 'provideniya', 'iqaluit', 'mys shmidta', 'denizli', 'san cristobal', 'alyangula', 'cape town', 'svilajnac', 'arraial do cabo', 'faanui', 'kapaa', 'andros town', 'vaini', 'constitucion', 'dolinsk', 'arbagar', 'tiksi', 'port moresby', 'puerto ayora', 'okhotsk', 'samus', 'klaksvik', 'paraiso', 'barentsburg', 'jamestown', 'longyearbyen', 'brigantine', 'nizhneyansk', 'tsihombe', 'saint george', 'hasaki', 'illoqqortoormiut', 'leningradskiy', 'souillac', 'santa cruz del sur', 'dikson', 'vestmannaeyjar', 'hualmay', 'albania', 'bathurst', 'kathmandu', 'hithadhoo', 'mexico', 'kaeo', 'vanimo', 'playas', 'norman wells', 'nemuro', 'arlit', 'bredasdorp', 'ola', 'sentyabrskiy', 'hat yai', 'sao jose da coroa grande', 'beloha', 'tumannyy', 'mahebourg', 'bengkulu', 'olutanga', 'margate', 'champoton', 'myitkyina', 'harper', 'kijang', 'izhma', 'tabuk', 'castro', 'victoria', 'bluff', 'kurilsk', 'villa maria', 'lahaina', 'bumbesti-jiu', 'yumen', 'hurghada', 'bilibino', 'barrow', 'taolanaro', 'luderitz', 'cap malheureux', 'moron', 'pangnirtung', 'khatanga', 'san patricio', 'saint-augustin', 'kabompo', 'blagoyevo', 'mahadday weyne', 'ramos arizpe', 'hyderabad', 'bathsheba', 'mataura', 'upernavik', 'iquitos', 'avarua', 'bethel', 'paidha', 'atasu', 'balimo', 'rongcheng', 'poum', 'esperance', 'gambo', 'fort nelson', 'high level', 'yanan', 'genhe', 'erenhot', 'sanming', 'east london', 'krasnoselkup', 'hambantota', 'yirol', 'san andres', 'belushya guba', 'kholodnyy', 'dunhua', 'ca mau', 'vaitupu', 'avera', 'warren', 'pressbaum', 'mogok', 'fortuna', 'chokurdakh', 'bargal', 'saint-philippe', 'sungurlu', 'leirvik', 'oro valley', 'lakatoro', 'severo-kurilsk', 'qaanaaq', 'sola', 'tasiilaq', 'cabo san lucas', 'samusu', 'san quintin', 'mount gambier', 'lolua', 'ahipara', 'alofi', 'georgetown', 'hamilton', 'labuan', 'arman', 'pindi gheb', 'portland', 'calabozo', 'grindavik', 'sept-iles', 'bardiyah', 'emba', 'port macquarie', 'kudahuvadhoo', 'aksu', 'lunca ilvei', 'amderma', 'saldanha', 'lagoa', 'palagonia', 'takoradi', 'damaturu', 'vagur', 'pilibanga', 'utiroa', 'college', 'hohhot', 'dali', 'santa cruz', 'liverpool', 'mackenzie', 'husavik', 'gewane', 'premnitz', 'warqla', 'petropavlovka', 'thompson', 'tiznit', 'fairbanks', 'nusaybin', 'port blair', 'dipkarpaz', 'yellowknife', 'abnub', 'vestmanna', 'karla', 'mahibadhoo', 'jaru', 'colombia', 'marsh harbour', 'coquimbo', 'olafsvik', 'nongan', 'sorvag', 'isangel', 'simpang', 'naze', 'correia pinto', 'coari', 'sharjah', 'port elizabeth', 'qeshm', 'new norfolk', 'whitecourt', 'bambous virieux', 'beyneu', 'gayny', 'pedasi', 'chuy', 'upata', 'les cayes', 'horsham', 'sinjah', 'abu dhabi', 'puerto del rosario', 'qui nhon', 'kavieng', 'marcona', 'fiesole', 'sao joao da barra', 'belyy yar', 'carlton', 'porbandar', 'ngukurr', 'mar del plata', 'quatre cocos', 'cabo frio', 'morros', 'bilma', 'mwene-ditu', 'ambunti', 'tuktoyaktuk', 'derzhavinsk', 'grand river south east', 'belaya gora', 'kikwit', 'aklavik', 'santa rosa', 'rio gallegos', 'ocozocoautla', 'geraldton', 'kyren', 'san carlos de bariloche', 'umzimvubu', 'svetlogorsk', 'aswan', 'ilhabela', 'mackay', 'port-gentil', 'goderich', 'guerrero negro', 'moshi', 'attawapiskat', 'cabedelo', 'tharad', 'korla', 'luena', 'ancud', 'bo phloi', 'sorland', 'dwarahat', 'kasongo', 'chapais', 'sur', 'caravelas', 'ituni', 'viesca', 'jinchang', 'rungata', 'pingzhuang', 'katsuura', 'deer lake', 'kruisfontein', 'macau', 'namatanai', ' ...

# %%
# 7. Add data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests limitation of your subscription type. Please choose the proper subscription http://openweathermap.org/price'}
