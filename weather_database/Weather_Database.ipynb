# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# 5. Perform an API call with the OpenWeatherMap.

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6. Retrieve the following information from the API call:
    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record %s of set %s | %s" % (record_count,set_count,city))
       
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_descrip = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_current_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | jamestown
# Processing Record 2 of set 1 | albany
# Processing Record 3 of set 1 | vokhtoga
# Processing Record 4 of set 1 | santa fe
# Processing Record 5 of set 1 | tongren
# Processing Record 6 of set 1 | ushuaia
# Processing Record 7 of set 1 | raudeberg
# Processing Record 8 of set 1 | marsabit
# Processing Record 9 of set 1 | portland
# Processing Record 10 of set 1 | yellowknife
# Processing Record 11 of set 1 | hithadhoo
# Processing Record 12 of set 1 | kamenka
# Processing Record 13 of set 1 | whitehorse
# Processing Record 14 of set 1 | smithers
# Processing Record 15 of set 1 | naze
# Processing Record 16 of set 1 | rikitea
# Processing Record 17 of set 1 | port elizabeth
# Processing Record 18 of set 1 | victoria
# Processing Record 19 of set 1 | barrow
# Processing Record 20 of set 1 | arraial do cabo
# Processing Record 21 of set 1 | samarai
# Processing Record 22 of set 1 | bethel
# Processing Record 23 of set 1 | mataura
# Processing Record 24 of set 1 | tuktoyaktuk
# Processing Record 25 of set 1 | anshun
# Processing Record 26 of set 1 | iza
# Processing Record 27 of set 1 | katsuura
# Processing Record 28 of set 1 | ji-parana
# City not found. Skipping...
# Processing Record 29 of set 1 | kortkeros
# Processing Record 30 of set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of set 1 | buqayq
# City not found. Skipping...
# Processing Record 32 of set 1 | puerto leguizamo
# Processing Record 33 of set 1 | dingle
# Processing Record 34 of set 1 | yar-sale
# Processing Record 35 of set 1 | qaanaaq
# Processing Record 36 of set 1 | lata
# Processing Record 37 of set 1 | khatanga
# Processing Record 38 of set 1 | cidreira
# Processing Record 39 of set 1 | tabou
# Processing Record 40 of set 1 | butaritari
# Processing Record 41 of set 1 | atuona
# Processing Record 42 of set 1 | saint-philippe
# Processing Record 43 of set 1 | torbay
# Processing Record 44 of set 1 | aden
# Processing Record 45 of set 1 | puerto ayora
# Processing Record 46 of set 1 | karratha
# Processing Record 47 of set 1 | elizabeth city
# Processing Record 48 of set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of set 1 | hermanus
# Processing Record 50 of set 1 | dabat
# Processing Record 1 of set 2 | tiznit
# Processing Record 2 of set 2 | pimentel
# Processing Record 3 of set 2 | dezful
# Processing Record 4 of set 2 | otradnoye
# Processing Record 5 of set 2 | haines junction
# Processing Record 6 of set 2 | busselton
# Processing Record 7 of set 2 | port macquarie
# Processing Record 8 of set 2 | biu
# Processing Record 9 of set 2 | ahipara
# Processing Record 10 of set 2 | punta arenas
# Processing Record 11 of set 2 | avarua
# Processing Record 12 of set 2 | minab
# Processing Record 13 of set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of set 2 | labuhan
# Processing Record 15 of set 2 | chokurdakh
# Processing Record 16 of set 2 | saint-augustin
# Processing Record 17 of set 2 | pasewalk
# Processing Record 18 of set 2 | chuy
# Processing Record 19 of set 2 | pangnirtung
# Processing Record 20 of set 2 | rondonopolis
# Processing Record 21 of set 2 | hilo
# Processing Record 22 of set 2 | banda aceh
# Processing Record 23 of set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of set 2 | klaksvik
# Processing Record 25 of set 2 | yatou
# Processing Record 26 of set 2 | jardim
# Processing Record 27 of set 2 | hofn
# Processing Record 28 of set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of set 2 | vaitupu
# City not found. Skipping...
# Processing Record 30 of set 2 | ribeira grande
# Processing Record 31 of set 2 | terrace
# Processing Record 32 of set 2 | abu kamal
# Processing Record 33 of set 2 | carnarvon
# Processing Record 34 of set 2 | talnakh
# Processing Record 35 of set 2 | clyde river
# Processing Record 36 of set 2 | la ronge
# Processing Record 37 of set 2 | nikolskoye
# Processing Record 38 of set 2 | tasiilaq
# Processing Record 39 of set 2 | kodiak
# Processing Record 40 of set 2 | panchagarh
# Processing Record 41 of set 2 | longyearbyen
# Processing Record 42 of set 2 | port-gentil
# Processing Record 43 of set 2 | kasongo
# Processing Record 44 of set 2 | tabuk
# Processing Record 45 of set 2 | cape town
# Processing Record 46 of set 2 | santa cruz cabralia
# Processing Record 47 of set 2 | bredasdorp
# Processing Record 48 of set 2 | thompson
# Processing Record 49 of set 2 | marcona
# City not found. Skipping...
# Processing Record 50 of set 2 | te anau
# Processing Record 1 of set 3 | georgetown
# Processing Record 2 of set 3 | dikson
# Processing Record 3 of set 3 | sitka
# Processing Record 4 of set 3 | east london
# Processing Record 5 of set 3 | bathsheba
# Processing Record 6 of set 3 | hobart
# Processing Record 7 of set 3 | muroto
# Processing Record 8 of set 3 | bluff
# Processing Record 9 of set 3 | leh
# Processing Record 10 of set 3 | itarema
# Processing Record 11 of set 3 | boyolangu
# Processing Record 12 of set 3 | hasaki
# Processing Record 13 of set 3 | milingimbi
# City not found. Skipping...
# Processing Record 14 of set 3 | excelsior springs
# Processing Record 15 of set 3 | naifaru
# Processing Record 16 of set 3 | port alfred
# Processing Record 17 of set 3 | saint-louis
# Processing Record 18 of set 3 | ilulissat
# Processing Record 19 of set 3 | tura
# Processing Record 20 of set 3 | manggar
# Processing Record 21 of set 3 | karaul
# City not found. Skipping...
# Processing Record 22 of set 3 | saldanha
# Processing Record 23 of set 3 | liverpool
# Processing Record 24 of set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of set 3 | jaque
# Processing Record 26 of set 3 | peleduy
# Processing Record 27 of set 3 | ugoofaaru
# Processing Record 28 of set 3 | mahebourg
# Processing Record 29 of set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of set 3 | prince george
# Processing Record 31 of set 3 | saskylakh
# Processing Record 32 of set 3 | hamilton
# Processing Record 33 of set 3 | svetlyy
# Processing Record 34 of set 3 | petropavlovsk-kamchatskiy
# Processing Record 35 of set 3 | upernavik
# Processing Record 36 of set 3 | vila franca do campo
# Processing Record 37 of set 3 | beloha
# Processing Record 38 of set 3 | cockburn town
# Processing Record 39 of set 3 | kieta
# Processing Record 40 of set 3 | isangel
# Processing Record 41 of set 3 | sao filipe
# Processing Record 42 of set 3 | hokitika
# Processing Record 43 of set 3 | svetlaya
# Processing Record 44 of set 3 | san fernando
# Processing Record 45 of set 3 | brusyliv
# Processing Record 46 of set 3 | pekalongan
# Processing Record 47 of set 3 | vaini
# Processing Record 48 of set 3 | ventspils
# Processing Record 49 of set 3 | nha trang
# Processing Record 50 of set 3 | puerto quijarro
# Processing Record 1 of set 4 | cherskiy
# Processing Record 2 of set 4 | almaznyy
# Processing Record 3 of set 4 | varhaug
# Processing Record 4 of set 4 | marawi
# Processing Record 5 of set 4 | balagansk
# Processing Record 6 of set 4 | saleaula
# City not found. Skipping...
# Processing Record 7 of set 4 | khonuu
# City not found. Skipping...
# Processing Record 8 of set 4 | nemuro
# Processing Record 9 of set 4 | puerto baquerizo moreno
# Processing Record 10 of set 4 | roblin
# Processing Record 11 of set 4 | ulaanbaatar
# Processing Record 12 of set 4 | souillac
# Processing Record 13 of set 4 | jalor
# Processing Record 14 of set 4 | kapaa
# Processing Record 15 of set 4 | tabiauea
# City not found. Skipping...
# Processing Record 16 of set 4 | taolanaro
# City not found. Skipping...
# Processing Record 17 of set 4 | jumla
# Processing Record 18 of set 4 | tiksi
# Processing Record 19 of set 4 | surman
# Processing Record 20 of set 4 | geraldton
# Processing Record 21 of set 4 | izyum
# Processing Record 22 of set 4 | brae
# Processing Record 23 of set 4 | kijang
# Processing Record 24 of set 4 | nileshwar
# Processing Record 25 of set 4 | yumen
# Processing Record 26 of set 4 | vilyuysk
# Processing Record 27 of set 4 | niamey
# Processing Record 28 of set 4 | narsaq
# Processing Record 29 of set 4 | faanui
# Processing Record 30 of set 4 | bardiyah
# Processing Record 31 of set 4 | padang
# Processing Record 32 of set 4 | lolua
# City not found. Skipping...
# Processing Record 33 of set 4 | castro
# Processing Record 34 of set 4 | raga
# Processing Record 35 of set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of set 4 | harrai
# Processing Record 37 of set 4 | kuantan
# Processing Record 38 of set 4 | new norfolk
# Processing Record 39 of set 4 | gizo
# Processing Record 40 of set 4 | ixtapa
# Processing Record 41 of set 4 | manavalakurichi
# Processing Record 42 of set 4 | saint anthony
# Processing Record 43 of set 4 | swan hill
# Processing Record 44 of set 4 | norman wells
# Processing Record 45 of set 4 | prince rupert
# Processing Record 46 of set 4 | ha tinh
# Processing Record 47 of set 4 | vigrestad
# Processing Record 48 of set 4 | bengkulu
# Processing Record 49 of set 4 | leningradskiy
# Processing Record 50 of set 4 | kaitangata
# Processing Record 1 of set 5 | terrace bay
# Processing Record 2 of set 5 | tsihombe
# City not found. Skipping...
# Processing Record 3 of set 5 | ovsyanka
# Processing Record 4 of set 5 | lavrentiya
# Processing Record 5 of set 5 | airai
# Processing Record 6 of set 5 | wehr
# Processing Record 7 of set 5 | araouane
# Processing Record 8 of set 5 | viedma
# Processing Record 9 of set 5 | port blair
# Processing Record 10 of set 5 | pevek
# Processing Record 11 of set 5 | minggang
# Processing Record 12 of set 5 | asosa
# Processing Record 13 of set 5 | marovoay
# Processing Record 14 of set 5 | salinopolis
# Processing Record 15 of set 5 | sorland
# Processing Record 16 of set 5 | hillsborough
# Processing Record 17 of set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of set 5 | pekan
# Processing Record 19 of set 5 | oia
# Processing Record 20 of set 5 | loveland
# Processing Record 21 of set 5 | falealupo
# City not found. Skipping...
# Processing Record 22 of set 5 | henties bay
# Processing Record 23 of set 5 | esperance
# Processing Record 24 of set 5 | mareeba
# Processing Record 25 of set 5 | la palma
# Processing Record 26 of set 5 | shimoda
# Processing Record 27 of set 5 | guerrero negro
# Processing Record 28 of set 5 | mandera
# Processing Record 29 of set 5 | college
# Processing Record 30 of set 5 | anantapur
# Processing Record 31 of set 5 | iqaluit
# Processing Record 32 of set 5 | bhikangaon
# Processing Record 33 of set 5 | bonfim
# Processing Record 34 of set 5 | srivardhan
# Processing Record 35 of set 5 | harper
# Processing Record 36 of set 5 | malpe
# Processing Record 37 of set 5 | nosy varika
# Processing Record 38 of set 5 | yeppoon
# Processing Record 39 of set 5 | montecristi
# Processing Record 40 of set 5 | faya
# Processing Record 41 of set 5 | khapa
# Processing Record 42 of set 5 | hovd
# Processing Record 43 of set 5 | botosesti-paia
# City not found. Skipping...
# Processing Record 44 of set 5 | piranshahr
# Processing Record 45 of set 5 | kendari
# Processing Record 46 of set 5 | colares
# Processing Record 47 of set 5 | grand gaube
# Processing Record 48 of set 5 | severo-kurilsk
# Processing Record 49 of set 5 | zyryanka
# Processing Record 50 of set 5 | porto seguro
# Processing Record 1 of set 6 | molina
# Processing Record 2 of set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of set 6 | muros
# Processing Record 4 of set 6 | jaumave
# Processing Record 5 of set 6 | sao joao da barra
# Processing Record 6 of set 6 | port lincoln
# Processing Record 7 of set 6 | coihaique
# Processing Record 8 of set 6 | kirakira
# Processing Record 9 of set 6 | tres arroyos
# Processing Record 10 of set 6 | eyl
# Processing Record 11 of set 6 | vao
# Processing Record 12 of set 6 | nioro
# Processing Record 13 of set 6 | lebu
# Processing Record 14 of set 6 | aksha
# Processing Record 15 of set 6 | alice springs
# Processing Record 16 of set 6 | lasa
# Processing Record 17 of set 6 | rawson
# Processing Record 18 of set 6 | verkhnyaya inta
# Processing Record 19 of set 6 | las juntas
# Processing Record 20 of set 6 | rocha
# Processing Record 21 of set 6 | bambous virieux
# Processing Record 22 of set 6 | motygino
# Processing Record 23 of set 6 | svetlogorsk
# Processing Record 24 of set 6 | kudahuvadhoo
# Processing Record 25 of set 6 | northam
# Processing Record 26 of set 6 | meyungs
# City not found. Skipping...
# Processing Record 27 of set 6 | myitkyina
# Processing Record 28 of set 6 | ossora
# Processing Record 29 of set 6 | caravelas
# Processing Record 30 of set 6 | susanville
# Processing Record 31 of set 6 | pangody
# Processing Record 32 of set 6 | sri aman
# Processing Record 33 of set 6 | general roca
# Processing Record 34 of set 6 | nicolas bravo
# Processing Record 35 of set 6 | korla
# Processing Record 36 of set 6 | guangyuan
# Processing Record 37 of set 6 | amderma
# City not found. Skipping...
# Processing Record 38 of set 6 | nerchinsk
# Processing Record 39 of set 6 | kurilsk
# Processing Record 40 of set 6 | kuche
# City not found. Skipping...
# Processing Record 41 of set 6 | alta floresta
# Processing Record 42 of set 6 | fairbanks
# Processing Record 43 of set 6 | kilkenny
# Processing Record 44 of set 6 | san felipe
# Processing Record 45 of set 6 | porterville
# Processing Record 46 of set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 47 of set 6 | olafsvik
# Processing Record 48 of set 6 | paamiut
# Processing Record 49 of set 6 | quelimane
# Processing Record 50 of set 6 | riyadh
# Processing Record 1 of set 7 | itoman
# Processing Record 2 of set 7 | waddan
# Processing Record 3 of set 7 | maungaturoto
# Processing Record 4 of set 7 | bereda
# Processing Record 5 of set 7 | quisqueya
# Processing Record 6 of set 7 | seoul
# Processing Record 7 of set 7 | mahanoro
# Processing Record 8 of set 7 | manokwari
# Processing Record 9 of set 7 | lompoc
# Processing Record 10 of set 7 | kadoma
# Processing Record 11 of set 7 | eureka
# Processing Record 12 of set 7 | bur gabo
# City not found. Skipping...
# Processing Record 13 of set 7 | ponta do sol
# Processing Record 14 of set 7 | omsukchan
# Processing Record 15 of set 7 | bar
# Processing Record 16 of set 7 | mercedes
# Processing Record 17 of set 7 | alugan
# Processing Record 18 of set 7 | bar harbor
# Processing Record 19 of set 7 | pionki
# Processing Record 20 of set 7 | sarh
# Processing Record 21 of set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of set 7 | san patricio
# Processing Record 23 of set 7 | staunton
# Processing Record 24 of set 7 | pascagoula
# Processing Record 25 of set 7 | alofi
# Processing Record 26 of set 7 | sioux lookout
# Processing Record 27 of set 7 | hunfeld
# Processing Record 28 of set 7 | beringovskiy
# Processing Record 29 of set 7 | luderitz
# Processing Record 30 of set 7 | iquitos
# Processing Record 31 of set 7 | jalu
# Processing Record 32 of set 7 | ouadda
# Processing Record 33 of set 7 | nome
# Processing Record 34 of set 7 | saint-pierre
# Processing Record 35 of set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of set 7 | naftah
# City not found. Skipping...
# Processing Record 37 of set 7 | carballo
# Processing Record 38 of set 7 | ayios matthaios
# City not found. Skipping...
# Processing Record 39 of set 7 | ulladulla
# Processing Record 40 of set 7 | utiroa
# City not found. Skipping...
# Processing Record 41 of set 7 | atambua
# Processing Record 42 of set 7 | tumannyy
# City not found. Skipping...
# Processing Record 43 of set 7 | laguna de perlas
# Processing Record 44 of set 7 | diu
# Processing Record 45 of set 7 | mamontovo
# Processing Record 46 of set 7 | ritchie
# Processing Record 47 of set 7 | oranjestad
# Processing Record 48 of set 7 | nakamura
# Processing Record 49 of set 7 | kenai
# Processing Record 50 of set 7 | esna
# Processing Record 1 of set 8 | kasongo-lunda
# Processing Record 2 of set 8 | kruisfontein
# Processing Record 3 of set 8 | kaikalur
# Processing Record 4 of set 8 | asfi
# Processing Record 5 of set 8 | bosaso
# Processing Record 6 of set 8 | bay roberts
# Processing Record 7 of set 8 | chicama
# Processing Record 8 of set 8 | levski
# Processing Record 9 of set 8 | girne
# Processing Record 10 of set 8 | brodowski
# Processing Record 11 of set 8 | jutai
# Processing Record 12 of set 8 | kahului
# Processing Record 13 of set 8 | russell
# Processing Record 14 of set 8 | tiarei
# Processing Record 15 of set 8 | bang saphan
# Processing Record 16 of set 8 | macapa
# Processing Record 17 of set 8 | ancud
# Processing Record 18 of set 8 | jatibonico
# Processing Record 19 of set 8 | bhattiprolu
# Processing Record 20 of set 8 | bowen
# Processing Record 21 of set 8 | porto empedocle
# Processing Record 22 of set 8 | kiama
# Processing Record 23 of set 8 | acarau
# Processing Record 24 of set 8 | angoche
# Processing Record 25 of set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 26 of set 8 | santa cruz
# Processing Record 27 of set 8 | asau
# Processing Record 28 of set 8 | popondetta
# Processing Record 29 of set 8 | shingu
# Processing Record 30 of set 8 | bairiki
# Processing Record 31 of set 8 | ambovombe
# Processing Record 32 of set 8 | vanderhoof
# Processing Record 33 of set 8 | zhaocheng
# City not found. Skipping...
# Processing Record 34 of set 8 | baniyas
# Processing Record 35 of set 8 | iskateley
# Processing Record 36 of set 8 | polunochnoye
# Processing Record 37 of set 8 | ust-nera
# Processing Record 38 of set 8 | moses lake
# Processing Record 39 of set 8 | hualmay
# Processing Record 40 of set 8 | sovetskaya gavan
# Processing Record 41 of set 8 | sobolevo
# Processing Record 42 of set 8 | melilla
# Processing Record 43 of set 8 | lorengau
# Processing Record 44 of set 8 | bandar-e lengeh
# Processing Record 45 of set 8 | paita
# Processing Record 46 of set 8 | flin flon
# Processing Record 47 of set 8 | oranjemund
# Processing Record 48 of set 8 | aksu
# Processing Record 49 of set 8 | stephenville
# Processing Record 50 of set 8 | labutta
# City not found. Skipping...
# Processing Record 1 of set 9 | pisco
# Processing Record 2 of set 9 | pitimbu
# Processing Record 3 of set 9 | diffa
# Processing Record 4 of set 9 | minna
# Processing Record 5 of set 9 | cambridge
# Processing Record 6 of set 9 | hobyo
# Processing Record 7 of set 9 | kismayo
# Processing Record 8 of set 9 | aberdeen
# Processing Record 9 of set 9 | hambantota
# Processing Record 10 of set 9 | chara
# Processing Record 11 of set 9 | sao paulo de olivenca
# Processing Record 12 of set 9 | jacareacanga
# Processing Record 13 of set 9 | komsomolskiy
# Processing Record 14 of set 9 | mar del plata
# Processing Record 15 of set 9 | kaeo
# Processing Record 16 of set 9 | boali
# Processing Record 17 of set 9 | mount isa
# Processing Record 18 of set 9 | chabahar
# Processing Record 19 of set 9 | lucapa
# Processing Record 20 of set 9 | gainesville
# Processing Record 21 of set 9 | maghama
# City not found. Skipping...
# Processing Record 22 of set 9 | okha
# Processing Record 23 of set 9 | ipixuna
# Processing Record 24 of set 9 | mbini
# Processing Record 25 of set 9 | la tuque
# Processing Record 26 of set 9 | praia da vitoria
# Processing Record 27 of set 9 | hirara
# Processing Record 28 of set 9 | zhigansk
# Processing Record 29 of set 9 | waipawa
# Processing Record 30 of set 9 | provideniya
# Processing Record 31 of set 9 | bandarbeyla
# Processing Record 32 of set 9 | champerico
# Processing Record 33 of set 9 | mali
# Processing Record 34 of set 9 | margate
# Processing Record 35 of set 9 | hervey bay
# Processing Record 36 of set 9 | nantucket
# Processing Record 37 of set 9 | ishigaki
# Processing Record 38 of set 9 | usinsk
# Processing Record 39 of set 9 | ocampo
# Processing Record 40 of set 9 | sola
# Processing Record 41 of set 9 | brownsville
# Processing Record 42 of set 9 | myaundzha
# Processing Record 43 of set 9 | bundaberg
# Processing Record 44 of set 9 | golden
# Processing Record 45 of set 9 | kamskiye polyany
# Processing Record 46 of set 9 | srednekolymsk
# Processing Record 47 of set 9 | bikaner
# Processing Record 48 of set 9 | sistranda
# Processing Record 49 of set 9 | nabari
# Processing Record 50 of set 9 | phan rang
# City not found. Skipping...
# Processing Record 1 of set 10 | sembakung
# Processing Record 2 of set 10 | sayyan
# Processing Record 3 of set 10 | gari
# Processing Record 4 of set 10 | vostok
# Processing Record 5 of set 10 | livingston
# Processing Record 6 of set 10 | savannah bight
# Processing Record 7 of set 10 | zabaykalsk
# Processing Record 8 of set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 9 of set 10 | aklavik
# Processing Record 10 of set 10 | fare
# Processing Record 11 of set 10 | udimskiy
# Processing Record 12 of set 10 | vaitape
# Processing Record 13 of set 10 | tessalit
# Processing Record 14 of set 10 | cabo san lucas
# Processing Record 15 of set 10 | dong hoi
# Processing Record 16 of set 10 | san cristobal
# Processing Record 17 of set 10 | namatanai
# Processing Record 18 of set 10 | masallatah
# Processing Record 19 of set 10 | gorontalo
# Processing Record 20 of set 10 | tazovskiy
# Processing Record 21 of set 10 | salym
# Processing Record 22 of set 10 | ngukurr
# City not found. Skipping...
# Processing Record 23 of set 10 | timbiqui
# Processing Record 24 of set 10 | sambava
# Processing Record 25 of set 10 | acajutla
# Processing Record 26 of set 10 | bonavista
# Processing Record 27 of set 10 | atar
# Processing Record 28 of set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 29 of set 10 | abeche
# Processing Record 30 of set 10 | nuuk
# Processing Record 31 of set 10 | arbroath
# Processing Record 32 of set 10 | prachuap khiri khan
# Processing Record 33 of set 10 | saint george
# Processing Record 34 of set 10 | algeciras
# Processing Record 35 of set 10 | villarrica
# Processing Record 36 of set 10 | sanchazi
# Processing Record 37 of set 10 | calvinia
# Processing Record 38 of set 10 | wanxian
# Processing Record 39 of set 10 | avera
# Processing Record 40 of set 10 | warqla
# City not found. Skipping...
# Processing Record 41 of set 10 | kopavogur
# Processing Record 42 of set 10 | tingo maria
# Processing Record 43 of set 10 | berlevag
# Processing Record 44 of set 10 | portales
# Processing Record 45 of set 10 | zermatt
# Processing Record 46 of set 10 | sao bras de alportel
# Processing Record 47 of set 10 | arlit
# Processing Record 48 of set 10 | pryazha
# Processing Record 49 of set 10 | altamira
# Processing Record 50 of set 10 | karatau
# Processing Record 1 of set 11 | panguna
# Processing Record 2 of set 11 | kamyshla
# Processing Record 3 of set 11 | chapais
# Processing Record 4 of set 11 | batagay
# Processing Record 5 of set 11 | urengoy
# Processing Record 6 of set 11 | evensk
# Processing Record 7 of set 11 | north bend
# Processing Record 8 of set 11 | bacolod
# Processing Record 9 of set 11 | panaba
# Processing Record 10 of set 11 | shache
# Processing Record 11 of set 11 | winnemucca
# Processing Record 12 of set 11 | kuytun
# Processing Record 13 of set 11 | kupang
# Processing Record 14 of set 11 | flinders
# Processing Record 15 of set 11 | tavda
# Processing Record 16 of set 11 | dongsheng
# Processing Record 17 of set 11 | luanda
# Processing Record 18 of set 11 | grimstad
# Processing Record 19 of set 11 | okhotsk
# Processing Record 20 of set 11 | lakatoro
# Processing Record 21 of set 11 | bubaque
# Processing Record 22 of set 11 | ratnagiri
# Processing Record 23 of set 11 | tarudant
# City not found. Skipping...
# Processing Record 24 of set 11 | kalisz
# Processing Record 25 of set 11 | lodja
# Processing Record 26 of set 11 | bell ville
# Processing Record 27 of set 11 | chuka
# Processing Record 28 of set 11 | gorzow wielkopolski
# Processing Record 29 of set 11 | conceicao do mato dentro
# Processing Record 30 of set 11 | pacific grove
# Processing Record 31 of set 11 | muli
# Processing Record 32 of set 11 | manta
# Processing Record 33 of set 11 | calama
# Processing Record 34 of set 11 | mount gambier
# Processing Record 35 of set 11 | matagami
# Processing Record 36 of set 11 | reynosa
# Processing Record 37 of set 11 | halifax
# Processing Record 38 of set 11 | barguzin
# Processing Record 39 of set 11 | nyurba
# Processing Record 40 of set 11 | kloulklubed
# Processing Record 41 of set 11 | morondava
# Processing Record 42 of set 11 | melchor de mencos
# Processing Record 43 of set 11 | dunmore town
# Processing Record 44 of set 11 | chilca
# Processing Record 45 of set 11 | kuruman
# Processing Record 46 of set 11 | milkovo
# Processing Record 47 of set 11 | byron bay
# Processing Record 48 of set 11 | coquimbo
# Processing Record 49 of set 11 | pochutla
# Processing Record 50 of set 11 | aguimes
# Processing Record 1 of set 12 | moron
# Processing Record 2 of set 12 | abeokuta
# Processing Record 3 of set 12 | adigeni
# Processing Record 4 of set 12 | igunga
# Processing Record 5 of set 12 | micheweni
# Processing Record 6 of set 12 | morehead
# Processing Record 7 of set 12 | rio gallegos
# Processing Record 8 of set 12 | yerbogachen
# Processing Record 9 of set 12 | kaspiysk
# Processing Record 10 of set 12 | marsh harbour
# Processing Record 11 of set 12 | codrington
# Processing Record 12 of set 12 | qaqortoq
# Processing Record 13 of set 12 | fortuna
# Processing Record 14 of set 12 | lerwick
# Processing Record 15 of set 12 | conakry
# Processing Record 16 of set 12 | wanning
# Processing Record 17 of set 12 | ilhabela
# Processing Record 18 of set 12 | vanimo
# Processing Record 19 of set 12 | buala
# Processing Record 20 of set 12 | gat
# Processing Record 21 of set 12 | gubkinskiy
# Processing Record 22 of set 12 | san quintin
# Processing Record 23 of set 12 | muborak
# Processing Record 24 of set 12 | amontada
# Processing Record 25 of set 12 | kavieng
# Processing Record 26 of set 12 | port hedland
# Processing Record 27 of set 12 | russkaya polyana
# Processing Record 28 of set 12 | palmer
# Processing Record 29 of set 12 | ponta delgada
# Processing Record 30 of set 12 | akyab
# Processing Record 31 of set 12 | balakhninskiy
# Processing Record 32 of set 12 | maniitsoq
# Processing Record 33 of set 12 | ituni
# City not found. Skipping...
# Processing Record 34 of set 12 | bembereke
# Processing Record 35 of set 12 | cumra
# Processing Record 36 of set 12 | kutoarjo
# Processing Record 37 of set 12 | grand-lahou
# Processing Record 38 of set 12 | buckingham
# Processing Record 39 of set 12 | dakar
# Processing Record 40 of set 12 | port augusta
# Processing Record 41 of set 12 | kaka
# Processing Record 42 of set 12 | arvika
# Processing Record 43 of set 12 | suntar
# Processing Record 44 of set 12 | xai-xai
# Processing Record 45 of set 12 | vardo
# Processing Record 46 of set 12 | west wendover
# Processing Record 47 of set 12 | ahar
# Processing Record 48 of set 12 | alexandria
# Processing Record 49 of set 12 | makakilo city
# Processing Record 50 of set 12 | tombouctou
# Processing Record 1 of set 13 | lagoa
# Processing Record 2 of set 13 | severnyy-kospashskiy
# Processing Record 3 of set 13 | shiraz
# Processing Record 4 of set 13 | rio grande
# Processing Record 5 of set 13 | talavera de la reina
# Processing Record 6 of set 13 | springdale
# Processing Record 7 of set 13 | samusu
# City not found. Skipping...
# Processing Record 8 of set 13 | adrar
# Processing Record 9 of set 13 | skibbereen
# Processing Record 10 of set 13 | dunedin
# Processing Record 11 of set 13 | puerto padre
# Processing Record 12 of set 13 | namangan
# Processing Record 13 of set 13 | tizimin
# Processing Record 14 of set 13 | axim
# Processing Record 15 of set 13 | horasan
# Processing Record 16 of set 13 | rochegda
# Processing Record 17 of set 13 | safaga
# Processing Record 18 of set 13 | toliary
# City not found. Skipping...
# Processing Record 19 of set 13 | boffa
# Processing Record 20 of set 13 | artyk
# City not found. Skipping...
# Processing Record 21 of set 13 | san policarpo
# Processing Record 22 of set 13 | soubre
# Processing Record 23 of set 13 | lamu
# Processing Record 24 of set 13 | palmar de bravo
# Processing Record 25 of set 13 | syracuse
# Processing Record 26 of set 13 | kailua
# Processing Record 27 of set 13 | lincoln
# Processing Record 28 of set 13 | takoradi
# Processing Record 29 of set 13 | longlac
# City not found. Skipping...
# Processing Record 30 of set 13 | teya
# Processing Record 31 of set 13 | road town
# Processing Record 32 of set 13 | los llanos de aridane
# Processing Record 33 of set 13 | olean
# Processing Record 34 of set 13 | grand forks
# Processing Record 35 of set 13 | poum
# Processing Record 36 of set 13 | kidal
# Processing Record 37 of set 13 | sao desiderio
# Processing Record 38 of set 13 | kautokeino
# Processing Record 39 of set 13 | slonim
# Processing Record 40 of set 13 | otradnaya
# Processing Record 41 of set 13 | nedjo
# Processing Record 42 of set 13 | namibe
# Processing Record 43 of set 13 | meulaboh
# Processing Record 44 of set 13 | shonguy
# Processing Record 45 of set 13 | bon accord
# Processing Record 46 of set 13 | rafai
# Processing Record 47 of set 13 | alakurtti
# Processing Record 48 of set 13 | santa rosa
# Processing Record 49 of set 13 | theologos
# City not found. Skipping...
# Processing Record 50 of set 13 | bukama
# Processing Record 1 of set 14 | mastic beach
# Processing Record 2 of set 14 | arroyo
# Processing Record 3 of set 14 | rawannawi
# City not found. Skipping...
# Processing Record 4 of set 14 | sydney
# Processing Record 5 of set 14 | bilma
# Processing Record 6 of set 14 | mindelo
# Processing Record 7 of set 14 | mao
# Processing Record 8 of set 14 | temaraia
# City not found. Skipping...
# Processing Record 9 of set 14 | yola
# Processing Record 10 of set 14 | chagda
# City not found. Skipping...
# Processing Record 11 of set 14 | senanga
# Processing Record 12 of set 14 | nguru
# Processing Record 13 of set 14 | avdon
# Processing Record 14 of set 14 | mahon
# Processing Record 15 of set 14 | inhambane
# Processing Record 16 of set 14 | vila velha
# Processing Record 17 of set 14 | acari
# Processing Record 18 of set 14 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 19 of set 14 | pandan
# Processing Record 20 of set 14 | phan thiet
# Processing Record 21 of set 14 | boda
# Processing Record 22 of set 14 | tezu
# Processing Record 23 of set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 25 of set 14 | nikolayevka
# Processing Record 26 of set 14 | peniche
# Processing Record 27 of set 14 | aquidauana
# Processing Record 28 of set 14 | ranong
# Processing Record 29 of set 14 | broome
# Processing Record 30 of set 14 | saint albans
# Processing Record 31 of set 14 | comodoro rivadavia
# Processing Record 32 of set 14 | altar
# Processing Record 33 of set 14 | hohhot
# Processing Record 34 of set 14 | bayan
# Processing Record 35 of set 14 | shihezi
# Processing Record 36 of set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of set 14 | strezhevoy
# Processing Record 38 of set 14 | kollumerland
# City not found. Skipping...
# Processing Record 39 of set 14 | pemba
# Processing Record 40 of set 14 | mweka
# Processing Record 41 of set 14 | kashi
# Processing Record 42 of set 14 | raduzhnyy
# Processing Record 43 of set 14 | kerki
# City not found. Skipping...
# Processing Record 44 of set 14 | selty
# Processing Record 45 of set 14 | yulara
# Processing Record 46 of set 14 | bac lieu
# Processing Record 47 of set 14 | camacupa
# Processing Record 48 of set 14 | sundsvall
# Processing Record 49 of set 14 | broken hill
# Processing Record 50 of set 14 | oaxtepec
# Processing Record 1 of set 15 | christchurch
# Processing Record 2 of set 15 | southbridge
# Processing Record 3 of set 15 | tres picos
# Processing Record 4 of set 15 | nanortalik
# Processing Record 5 of set 15 | vestmannaeyjar
# Processing Record 6 of set 15 | port-cartier
# Processing Record 7 of set 15 | sampit
# Processing Record 8 of set 15 | bhuban
# Processing Record 9 of set 15 | dhidhdhoo
# Processing Record 10 of set 15 | gopalganj
# Processing Record 11 of set 15 | carauari
# Processing Record 12 of set 15 | laguna
# Processing Record 13 of set 15 | touros
# Processing Record 14 of set 15 | fortuna foothills
# Processing Record 15 of set 15 | saint-joseph
# Processing Record 16 of set 15 | buchanan
# Processing Record 17 of set 15 | bima
# Processing Record 18 of set 15 | qui nhon
# Processing Record 19 of set 15 | saint-maximin-la-sainte-baume
# Processing Record 20 of set 15 | ust-maya
# Processing Record 21 of set 15 | biak
# Processing Record 22 of set 15 | quatre cocos
# Processing Record 23 of set 15 | cururupu
# Processing Record 24 of set 15 | orcopampa
# Processing Record 25 of set 15 | portobelo
# Processing Record 26 of set 15 | tumpat
# Processing Record 27 of set 15 | juneau
# Processing Record 28 of set 15 | vagur
# Processing Record 29 of set 15 | coxim
# Processing Record 30 of set 15 | pokaran
# Processing Record 31 of set 15 | cravo norte
# Processing Record 32 of set 15 | havoysund
# Processing Record 33 of set 15 | gama
# Processing Record 34 of set 15 | shangqiu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 674

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=888944da311c141f4974381b35de871a&q=shangqiu

# %%
# 7. Add data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    jamestown  42.0970  -79.2353     35.01        93          90        9.22
# 1       albany  42.6001  -73.9662     37.99        67          97       14.56
# 2     vokhtoga  58.8147   41.0461     -9.45        88          41        2.84
# 3     santa fe -31.6333  -60.7000     81.00        29           0        8.99
# 4      tongren  27.7172  109.1853     38.91        75          36        2.06
# 5      ushuaia -54.8000  -68.3000     51.80        62          90        6.24
# 6    raudeberg  61.9875    5.1352     37.40        87          75       21.85
# 7     marsabit   2.3284   37.9899     72.95        54          70        7.49
# 8     portland  45.5234 -122.6762     46.99        93          90        3.44
# 9  yellowknife  62.4560 -114.3525     -2.00        78          90        4.61
#
#   Country      Current Description
# 0      US               light snow
# 1      US          overcast clouds
# 2      RU               light snow
# 3      AR                clear sky
# 4      CN         scattered clouds
# 5      AR                  drizzle
# 6      NO            broken clouds
# 7      KE            broken clouds
# 8      US  light intensity drizzle
# 9      CA               light snow

# %%
#reorder columns, new_column_order = ["column2", "column4", "column1"] 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
#assign new column order to DataFrame:df = df[new_column_order]
city_data_df = city_data_df[new_column_order]
city_data_df.head(14)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     jamestown      US  42.0970  -79.2353     35.01        93          90
# 1        albany      US  42.6001  -73.9662     37.99        67          97
# 2      vokhtoga      RU  58.8147   41.0461     -9.45        88          41
# 3      santa fe      AR -31.6333  -60.7000     81.00        29           0
# 4       tongren      CN  27.7172  109.1853     38.91        75          36
# 5       ushuaia      AR -54.8000  -68.3000     51.80        62          90
# 6     raudeberg      NO  61.9875    5.1352     37.40        87          75
# 7      marsabit      KE   2.3284   37.9899     72.95        54          70
# 8      portland      US  45.5234 -122.6762     46.99        93          90
# 9   yellowknife      CA  62.4560 -114.3525     -2.00        78          90
# 10    hithadhoo      MV  -0.6000   73.0833     81.57        71          86
# 11      kamenka      RU  51.3223   42.7678     -2.00        86         100
# 12   whitehorse      CA  60.7161 -135.0538     23.00        93          75
# 13     smithers      CA  54.7804 -127.1743     32.00       100          75
#
#     Wind Speed      Current Description
# 0         9.22               light snow
# 1        14.56          overcast clouds
# 2         2.84               light snow
# 3         8.99                clear sky
# 4         2.06         scattered clouds
# 5         6.24                  drizzle
# 6        21.85            broken clouds
# 7         7.49            broken clouds
# 8         3.44  light intensity drizzle
# 9         4.61               light snow
# 10        4.92          overcast clouds
# 11        4.43          overcast clouds
# 12        8.05            broken clouds
# 13        1.70            broken clouds

# %%
#8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
